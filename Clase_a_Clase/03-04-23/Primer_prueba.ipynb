# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %%
print ("Chau, me aburri")
# Out:
# Chau, me aburri

# %% [markdown]
# # Che, creo que el ejercicio ya lo pudieron resolver
#
# ## Subtitulo
#
# Nos queda por hacer:
# - Ni idea
#
# > Esto es una cita
#
# $\sum_n^2$

# %%
1 + 1
# Out:
# 2

# %%
4454534*232345
# Out:
# 1034988702230

# %%
"Hola" + " " + "mundo!"
# Out:
# 'Hola mundo!'

# %%
"Hola" * 3
# Out:
# 'HolaHolaHola'

# %%
"Hola" * 3.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-fc4c5f31aae7> in <cell line: 1>()
# ----> 1 "Hola" * 3.5
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
type(3.0)
# Out:
# float

# %%
type("Hola")
# Out:
# str

# %%
type(false)
# Out:
# bool

# %%
numero1 = input()
numero1 = int(numero1)
numero2 = input()
numero2 = int(numero2)
resultado = numero1 + numero2
print (f"El resultado de sumar {numero1} mas {numero2} da: {resultado}")
# Out:
# 23
# 42
# El resultado de multiplicar 23 por 42 da: 65

# %%
print (2 + 3)
print (5 + 8)
print ("Hola")
# Out:
# 5
# 13
# Hola

# %% [markdown]
# Celda de prueba
