# %%
edades = [18, 15, 17, 17, 16, 15, 16, 15, 19]

# %%
edades_2 = [21, 13, 17, 17, 16, 12, 16, 16, 15, 21, 112]

# %%
promedio = sum(edades)/len(edades)

# %%
promedio
# Out:
# 21.5

# %%
import pandas as pd

# %%
edades = pd.Series(edades)

# %%
edades
# Out:
# 0    18
# 1    15
# 2    17
# 3    17
# 4    16
# 5    15
# 6    16
# 7    15
# 8    19
# dtype: int64

# %%
edades.mean()
# Out:
# 16.444444444444443

# %%
edades.value_counts()
# Out:
# 15    3
# 17    2
# 16    2
# 18    1
# 19    1
# dtype: int64

# %%
edades.sort_values()
# Out:
# 1    15
# 5    15
# 7    15
# 4    16
# 6    16
# 2    17
# 3    17
# 0    18
# 8    19
# dtype: int64

# %%
edades_2 = pd.Series(edades_2)

# %%
edades_2.sort_values()
# Out:
# 5    12
# 1    13
# 7    15
# 4    16
# 6    16
# 2    17
# 3    17
# 0    21
# 8    21
# dtype: int64

# %%
edades_2.mean()
# Out:
# 25.09090909090909

# %%
edades_2.mode()
# Out:
# 0    16
# dtype: int64

# %%
edades.hist()
# Out:
# <Axes: >

# %%
edades_2.hist()
# Out:
# <Axes: >

# %%
edades.std()
# Out:
# 1.4240006242195884

# %%
edades_2.std()
# Out:
# 3.086709862908689
