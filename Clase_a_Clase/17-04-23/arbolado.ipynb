# %%
import pandas as pd

# %%
arbolado = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/atencion-ciudadana/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
# Out:
# <ipython-input-3-c82e2fe3a27d>:1: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   arbolado = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/atencion-ciudadana/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")

# %%
arbolado
# Out:
#              long        lat nro_registro tipo_activ  comuna manzana  \
# 0      -58.378563 -34.594902        26779     Lineal       1     NaN
# 1      -58.381532 -34.592319        30887     Lineal       1     NaN
# 2      -58.379103 -34.591939        30904     Lineal       1     NaN
# 3      -58.380710 -34.591548        31336     Lineal       1     NaN
# 4      -58.380710 -34.591548        31337     Lineal       1     NaN
# ...           ...        ...          ...        ...     ...     ...
# 370175        NaN        NaN       546140    Lineal       15     919
# 370176        NaN        NaN       546141    Lineal       15     919
# 370177        NaN        NaN       546142    Lineal       15     919
# 370178        NaN        NaN       546143    Lineal       15     919
# 370179        NaN        NaN       546144    Lineal       15     919
#
#              calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# ...

# %%
import matplotlib.pyplot as plt
#arbolado_red = arbolado.sample(10000)
plt.scatter(arbolado['long'], arbolado['lat'], color='red', s=0.1)

# %%
arbolado.columns
# Out:
# Index(['long', 'lat', 'nro_registro', 'tipo_activ', 'comuna', 'manzana',
#        'calle_nombre', 'calle_altura', 'calle_chapa', 'direccion_normalizada',
#        'ubicacion', 'nombre_cientifico', 'ancho_acera', 'estado_plantera',
#        'ubicacion_plantera', 'nivel_plantera', 'diametro_altura_pecho',
#        'altura_arbol'],
#       dtype='object')

# %%
arboles_altos = arbolado[arbolado['altura_arbol'] > 30]

# %%
ax.scatter(arboles_altos['long'],arboles_altos['lat'])

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 48.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 70.2 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd

# %%
comunas = gpd.read_file("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-educacion/comunas/comunas.geojson")

# %%
import seaborn as sns

# %%
sns.histplot(data = arbolado, x='altura_arbol')
# Out:
# <Axes: xlabel='altura_arbol', ylabel='Count'>

# %%
ax = comunas.plot()
ax.scatter(arboles_molestos['long'],arboles_molestos['lat'], color = 'red', marker = '*')

# %%
arboles_molestos = arbolado[arbolado['nombre_cientifico'] == 'Platanus x acerifolia']

# %%
arboles_altos['nombre_cientifico'].value_counts()
# Out:
# Platanus x acerifolia                240
# Tipuana tipu                          55
# Fraxinus pennsylvanica                48
# Ficus benjamina                       12
# Fraxinus excelsior                     9
# Melia azedarach                        9
# Jacaranda mimosifolia                  7
# Tilia cordata                          6
# No identificado                        5
# Fraxinus americana                     4
# Ligustrum lucidum                      3
# Robinia pseudoacacia                   3
# Tilia x moltkei                        3
# Acer palmatum                          2
# Syagrus romanzoffiana                  2
# Liquidambar styraciflua                2
# Lagerstroemia indica                   2
# Populus alba                           1
# Callistemon citrinus                   1
# Cupressus sempervirens f. stricta      1
# Nerium oleander                        1
# Citrus limon                           1
# Eucalyptus globulus                    1
# ...

# %%
ax.scatter(arboles_altos['long'],arboles_altos['lat'], color = 'red')

# %%
comunas
# Out:
#     ID          OBJETO  COMUNAS  \
# 0    1  LIMITE COMUNAL      2.0
# 1    3  LIMITE COMUNAL      6.0
# 2    6  LIMITE COMUNAL     10.0
# 3    7  LIMITE COMUNAL     11.0
# 4    8  LIMITE COMUNAL     12.0
# 5    9  LIMITE COMUNAL     14.0
# 6   11  LIMITE COMUNAL     15.0
# 7   15  LIMITE COMUNAL     13.0
# 8   13  LIMITE COMUNAL      4.0
# 9    2  LIMITE COMUNAL      5.0
# 10   4  LIMITE COMUNAL      7.0
# 11  10  LIMITE COMUNAL      3.0
# 12   5  LIMITE COMUNAL      9.0
# 13  12  LIMITE COMUNAL      8.0
# 14  14  LIMITE COMUNAL      1.0
#
#                                               BARRIOS     PERIMETRO  \
# 0                                            RECOLETA  21452.838648
# 1                                           CABALLITO  10990.964471
# 2   FLORESTA - MONTE CASTRO - VELEZ SARSFIELD - VE...  18332.037457
# 3   VILLA DEL PARQUE - VILLA  DEVOTO - VILLA GRAL....  19987.696155
# 4   COGHLAN - SAAVEDRA - VILLA PUEYRREDON - VILLA ...  17232.189372
# ...

# %%
arbolado['altura_arbol'].hist()
# Out:
# <Axes: >
