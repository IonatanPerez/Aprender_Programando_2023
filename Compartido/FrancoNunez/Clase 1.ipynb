# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %%
# Esto no se ejecuta
print ("3+5=") #Esto toma lo que esta dentro del parentesis como un texto porque tiene comillas
print (3+5) #Esto toma lo que esta dentro del parentesis como numeros
# Out:
# 3+5=
# 8

# %%
resultado = 3 + 5

# %%
print (resultado)
# Out:
# 8
