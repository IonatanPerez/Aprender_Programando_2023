# %%
import pandas as pd

# %%
from google.colab import files
import io

filesUploaded = files.upload()
# Out:
#      <input type="file" id="files-6f480eed-6188-4e5d-aaad-d428729f787b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f480eed-6188-4e5d-aaad-d428729f787b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
subtes_abc = pd.read_csv("202303_PAX15min-ABC.csv", sep=",")

# %%
subtes_abc
# Out:
#        FECHA;DESDE;HASTA;LINEA;MOLINETE;ESTACION;pax_pagos;pax_pases_pagos;pax_franq;pax_TOTAL
# 0       1/3/2023;05:15:00;05:30:00;LineaA;LineaA_CBarr...
# 1       1/3/2023;05:15:00;05:30:00;LineaC;LineaC_Retir...
# 2       1/3/2023;05:15:00;05:30:00;LineaA;LineaA_Carab...
# 3       1/3/2023;05:15:00;05:30:00;LineaB;LineaB_Calla...
# 4       1/3/2023;05:15:00;05:30:00;LineaA;LineaA_SnzPe...
# ...                                                   ...
# 574220  31/3/2023;23:30:00;23:45:00;LineaC;LineaC_Inde...
# 574221  31/3/2023;23:30:00;23:45:00;LineaC;LineaC_Reti...
# 574222  31/3/2023;23:30:00;23:45:00;LineaC;LineaC_Reti...
# 574223  31/3/2023;23:30:00;23:45:00;LineaC;LineaC_More...
# 574224  31/3/2023;23:30:00;23:45:00;LineaC;LineaC_Reti...
#
# [574225 rows x 1 columns]

# %%
import seaborn as sns

# %%
sns.barplot(data=subtes_abc, x="DESDE", y="pax_TOTAL")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-00f537cbf591> in <cell line: 1>()
# ----> 1 sns.barplot(data=subtes_abc, x="DESDE", y="pax_TOTAL")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# ...
