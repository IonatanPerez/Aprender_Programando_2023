# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = "/content/drive/MyDrive/202303_PAX15min-ABC.csv"
with open(file_path, 'r') as f:
  texto = f.read()

# %%
texto = texto.replace('"','')

# %%
with open(file_path+'modificado', 'w') as f:
  f.write(texto)

# %%
subtes_abc = pd.read_csv(file_path+'modificado', delimiter=';')

# %%
subtes_abc
# Out:
#             FECHA     DESDE     HASTA   LINEA                  MOLINETE  \
# 0        1/3/2023  05:15:00  05:30:00  LineaA   LineaA_CBarros_N_Turn01
# 1        1/3/2023  05:15:00  05:30:00  LineaC      LineaC_Retiro_Turn12
# 2        1/3/2023  05:15:00  05:30:00  LineaA  LineaA_Carabobo_O_Turn01
# 3        1/3/2023  05:15:00  05:30:00  LineaB   LineaB_CallaoB_S_Turn03
# 4        1/3/2023  05:15:00  05:30:00  LineaA   LineaA_SnzPena_S_Turn01
# ...           ...       ...       ...     ...                       ...
# 574220  31/3/2023  23:30:00  23:45:00  LineaC     LineaC_Indepen_Turn04
# 574221  31/3/2023  23:30:00  23:45:00  LineaC      LineaC_Retiro_Turn09
# 574222  31/3/2023  23:30:00  23:45:00  LineaC      LineaC_Retiro_Turn10
# 574223  31/3/2023  23:30:00  23:45:00  LineaC    LineaC_Moreno_N_Turn02
# 574224  31/3/2023  23:30:00  23:45:00  LineaC      LineaC_Retiro_Turn11
#
#               ESTACION  pax_pagos  pax_pases_pagos  pax_franq  pax_TOTAL
# 0        Castro Barros          2                0          0          2
# 1               Retiro         15                0          2         17
# 2             Carabobo          1                0          0          1
# 3             Callao.B          1                0          0          1
# 4          Saenz Peña           1                0          0          1
# ...                ...        ...              ...        ...        ...
# 574220   Independencia          0                0          1          1
# 574221          Retiro          1                0          0          1
# 574222          Retiro          0                0          1          1
# 574223  Mariano Moreno          1                0          0          1
# 574224          Retiro          3                0          0          3
#
# [574225 rows x 10 columns]
