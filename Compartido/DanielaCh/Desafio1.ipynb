# %% [markdown]
# 1

# %%
materias = ["matematica", "lengua", "filosofia", "derecho"]

# %%
materias
# Out:
# ['matematica', 'lengua', 'filosofia', 'derecho']

# %% [markdown]
# 2

# %%
materias.pop (0)
# Out:
# 'matematica'

# %%
materias
# Out:
# ['lengua', 'filosofia', 'derecho']

# %% [markdown]
# 3

# %%
materias.append ("quimica")

# %%
materias
# Out:
# ['lengua', 'filosofia', 'derecho', 'quimica']

# %% [markdown]
# 4

# %%
materias [2]
# Out:
# 'derecho'
