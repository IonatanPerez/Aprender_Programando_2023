# %% [markdown]
# 1

# %%
num1 = [3]
num2 = [8]

# %%
if  num2 > num1:
  print (f"El numero {num2} es mayor al numero {num1}")
else:
  print (f"El numero {num1} es igual al {num2}")
# Out:
# El numero [8] es mayor al numero [3]

# %% [markdown]
# 2

# %%
texto = ["Si no llueve"]

# %%
if texto:
  print (f"Podemos ir a la plaza")
else:
  print (f"Debemos quedarnos en casa")
# Out:
# Podemos ir a la plaza

# %% [markdown]
# 3
