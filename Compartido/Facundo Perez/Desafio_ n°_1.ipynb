# %% [markdown]
# Desafío 1 - Listas
#
# 1) Hacer una lista que contenga 3 materias de la escuela
#
# 2) Eliminar el primer registro de la lista
#
# 3) Agregar una materia más al final
#
# 4) Seleccionar el segundo elemento de la lista

# %%
#Primer punto 
materias = ["Matematicas", "Derecho", "Proyestos Organizacionales"] 
print(materias)
#Segundo punnto 
materias.remove ("Matematicas")
print(materias)
#Trecer punto
materias.append("Historia")
print(materias)
#Cuarto punto 
matrias [1]
print(materias)
# Out:
# ['Matematicas', 'Derecho', 'Proyestos Organizacionales']
# ['Derecho', 'Proyestos Organizacionales']
# ['Derecho', 'Proyestos Organizacionales', 'Historia']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-904943f7036a> in <cell line: 12>()
#      10
#      11 #Cuarto punto
# ---> 12 matrias [1]
#      13 print(materias)
#
# NameError: name 'matrias' is not defined
