# %% [markdown]
# ## Preguntas que nos podrian interesar
#
# - Cuanto se usa cada estacion de subte
# - Puestos de trabajos de en funcion de lugares del pais y sus habitantes
# - Cantidadd de razas de animales y en animales actuales y extintos.
# - Suscriptores de canales de youtube
# - Club con mas hinchas de pais
# - Lugares turisticos mas visitados en buenos aires.
# - Cantidad promedio de palabras por libro en español.

# %%
# Vamos a ver como abrir con datos en python
# Esto depende de como vienen los datos. En generel vamos a trabajar con archivos desdde cada columan esta separada

# %%
# vamos a importa una liberia 
import pandas

# %%
boca_de_subte = pandas.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/sbase/bocas-subte/bocas-de-subte.csv")

# %%
boca_de_subte
# Out:
#           long        lat   id linea                               estacion  \
# 0   -58.384068 -34.602106    1     D              TRIBUNALES - TEATRO COLÓN
# 1   -58.384372 -34.602394    2     D              TRIBUNALES - TEATRO COLÓN
# 2   -58.397250 -34.587804    3     H                              LAS HERAS
# 3   -58.403967 -34.598733    4     H                                CÓRDOBA
# 4   -58.405406 -34.603884    5     H                             CORRIENTES
# ..         ...        ...  ...   ...                                    ...
# 374 -58.369373 -34.604238  378     E                         CORREO CENTRAL
# 375 -58.370625 -34.603118  379     E                         CORREO CENTRAL
# 376 -58.370438 -34.603920  380     E                         CORREO CENTRAL
# 377 -58.370411 -34.604453  381     E                         CORREO CENTRAL
# 378 -58.391021 -34.583036  382     H  FACULTAD DE DERECHO - JULIETA LANTERI
#
# ...

# %%
boca_de_subte.dtypes
# Out:
# long          float64
# lat           float64
# id              int64
# linea          object
# estacion       object
# numero_de_      int64
# destino_bo     object
# lineas_de_     object
# cierra_fin       bool
# escalera_p       bool
# escalera_m       bool
# ascensor         bool
# rampa            bool
# salvaescal       bool
# calle          object
# altura          int64
# calle2         object
# barrio         object
# comuna         object
# observacio     object
# Objeto         object
# dom_norma      object
# dom_orig       object
# dtype: object

# %%
boca_de_subte['comuna'].value_counts()
# Out:
# Comuna 1     119
# Comuna 3      55
# Comuna 5      28
# Comuna 14     25
# Comuna 7      24
# Comuna 15     24
# Comuna 6      18
# Comuna 13     18
# Comuna 4      17
# Comuna 12     12
# Comuna 2      12
# Name: comuna, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(boca_de_subte['long'], boca_de_subte['lat'])
