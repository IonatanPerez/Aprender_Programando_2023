# %%
import pandas

# %%
arbolado = pandas.read_csv ("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/atencion-ciudadana/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
# Out:
# <ipython-input-7-2b3ff947ebd2>:1: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   arbolado = pandas.read_csv ("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/atencion-ciudadana/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")

# %%
bocas_subte = pandas.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/sbase/bocas-subte/bocas-de-subte.csv")
bocas_subte
bocas_subte.head()
# Out:
#         long        lat  id linea                   estacion  numero_de_  \
# 0 -58.384068 -34.602106   1     D  TRIBUNALES - TEATRO COLÓN           4
# 1 -58.384372 -34.602394   2     D  TRIBUNALES - TEATRO COLÓN           5
# 2 -58.397250 -34.587804   3     H                  LAS HERAS           1
# 3 -58.403967 -34.598733   4     H                    CÓRDOBA           1
# 4 -58.405406 -34.603884   5     H                 CORRIENTES           6
#
#                          destino_bo lineas_de_  cierra_fin  escalera_p  ...  \
# 0  a Catedral y Congreso de Tucumán        NaN        True        True  ...
# 1  a Catedral y Congreso de Tucumán        NaN        True        True  ...
# 2                      a Hospitales        NaN       False        True  ...
# 3           a Las Heras y Hopitales        NaN       False        True  ...
# 4          a Las Heras y Hospitales          B       False       False  ...
#
#    salvaescal       calle  altura  calle2       barrio    comuna  \
# ...

# %%
bocas_subte = pandas.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/sbase/bocas-subte/bocas-de-subte.csv")
bocas_subte
bocas_subte ["linea"]
bocas_subte ["linea"].value_counts() #cuenta la cantidad de bocas por linea
# Out:
# B    84
# A    83
# D    81
# E    63
# H    41
# C    27
# Name: linea, dtype: int64

# %%
arbolado = pandas.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/atencion-ciudadana/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
arbolado
# Out:
# <ipython-input-13-a4fbf139e9bd>:1: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   arbolado = pandas.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/atencion-ciudadana/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
#              long        lat nro_registro tipo_activ  comuna manzana  \
# 0      -58.378563 -34.594902        26779     Lineal       1     NaN
# 1      -58.381532 -34.592319        30887     Lineal       1     NaN
# 2      -58.379103 -34.591939        30904     Lineal       1     NaN
# 3      -58.380710 -34.591548        31336     Lineal       1     NaN
# 4      -58.380710 -34.591548        31337     Lineal       1     NaN
# ...           ...        ...          ...        ...     ...     ...
# 370175        NaN        NaN       546140    Lineal       15     919
# 370176        NaN        NaN       546141    Lineal       15     919
# ...

# %%
arbolado ["comuna"]
arbolado [ "comuna"].value_counts() #me trae en cada comuna cuantos arboles hay
# Out:
# 12    38818
# 11    37340
# 9     36405
# 10    33421
# 4     32346
# 15    29587
# 13    28287
# 7     25608
# 14    22417
# 8     21978
# 6     15591
# 5     15224
# 3     13320
# 1     12723
# 2      7115
# Name: comuna, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(arbolado["long"] , arbolado ["lat"] , color = "red") #le pido que dibuje con scatter las coordenadas y que lo haga rojo
