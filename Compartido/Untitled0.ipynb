# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
# Esto no se ejecuta
print ("3+5")
print (3+5) # Esto toma lo que esta dentro del parentesis como numeros porque tiene comillas
# Out:
# 3+5
# 8

# %%
 resultado = 3 + 5

# %%
print(resultado)
# Out:
# 8

# %%
# Tenemos variables tipo numericas
numero1 = 3 # Esto es una variable entera
numero2 = 0.3 # Esto es un float 
# Tenemos variables tipo string 
texto1 = "Esto es un texto"

# %%
nombres = ["Isabella","Daniela","Luciano","Joaquin","Milena"]
print ("Elija el numero de persona que quiere seleccionas")
seleeccion = input()
seleccion = int(seleccion)
seleccion = seleccion - 1
if seleccion < len( nombres):
print (f"El nombre seleccionado es {nombres[seleccion]}")
else:
  print ("No hay tantos nombres en la lista")
# Out:
#   File "<ipython-input-24-6a072e1e29aa>", line 7
#     print (f"el nombre seleccionado es {nombres[seleccion]}")
#     ^
# IndentationError: expected an indented block

# %%
# Queremos hacer una programa que me diga si el numero que ingreso mayor  menor a diez
numero_ingresado = input()
numero_ingresado = int(numero_ingresado)

if numero_ingresado >10:
  print(f"el numero {numero_ingresado} es mayor que 10")
else:
  if numero_ingresado < 10:
    print (f"El numero {numero_ingresado} es menor o igual que 10")
    else:
      print (f"")
# Out:
#   File "<ipython-input-22-e4a13eb8889c>", line 9
#     print ("Fin!)
#                  ^
# SyntaxError: EOL while scanning string literal
