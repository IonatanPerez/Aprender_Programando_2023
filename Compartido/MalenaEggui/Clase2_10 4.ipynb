# %%
print("hola mundo")
# Out:
# hola mundo

# %%
print("Ingrese su nombre")
nombre = input()

print(len(nombre)) #largo de una lista
# Out:
# Ingrese su nombre
# Male
# 4

# %%
#lista
nombres = ["Isabella", "Daniela", "Luciano", "Joaquin", "Milena"]
print("elija el número de persona que quiere seleccionar")
x = input()
x = int(x)
print(nombres[x-1])
# Out:
# elija el número de persona que quiere seleccionar
# 3
# Luciano

# %%
#mayor o menor
num_ingresado = input()
num_ingresado = int(num_ingresado)

if num_ingresado > 10:
  print(f"el número {num_ingresado} es mayor que 10")
else:
    print(f"el número {num_ingresado} es menor o igual que 10")
print("fin!")
# Out:
# 5
# el número 5 es menor que 10
# fin!

# %% [markdown]
# #  Desafio 1
# 1. Hacer una lista que contenga 3 materias de la escuela
#
# 2. Eliminar el primer registro de la lista
#
# 3. Agregar una materia más al final
#
# 4. Seleccionar el segundo elemento de la lista

# %%
#1
materias = ["energía y radiación", "Arte y ciencia", "lengua y literatura"]
print(materias)
#2
materias.remove("energía y radiación")
print(materias)
#3
materias.append("Química")
print(materias)
#4
print(materias[1])
# Out:
# ['energía y radiación', 'Arte y ciencia', 'lengua y literatura']
# ['Arte y ciencia', 'lengua y literatura']
# ['Arte y ciencia', 'lengua y literatura', 'Química']
# lengua y literatura

# %% [markdown]
# # Desafío 2 - Estructuras de Control
#
# 1. Definir 2 variables con números (num1 y num2). Crear una estructura condicional donde si los dos números son iguales se imprima "los dos números son iguales" (*if... else...*)
#
# 2. Crear una estructura condicional donde si "no llueve", "podemos ir a la plaza" y sino "debemos quedarnos en casa" (*if... else...*)
#
# 3. Definir una lista con 3 números. Crear una estructura iterativa donde se imprima cada número +2 (*for... in...*)
#
# 4. Crear una función que dado 2 números (parámetros), imprima el resultado de dividir el primer nùmero por el segundo (*def*)
#
# 5. Crea una función que reciba 2 números e incluya un condicional donde si el segundo número es 0 imprima "no se puede realizar esta operación" y sino realice una división entre el primer y el segundo número.

# %%
#1
num1 = 25
num2 = 7
if num1==num2:
  print("los dos números son iguales")
else:
  print("los dos números NO son iguales")
# Out:
# los dos números NO son iguales

# %%
#2
clima = " No LLueve "
if clima.lower().strip() == "no llueve":
  print("podemos ir a la plaza")
else:
  print("debemos quedarnos en casa")
# Out:
# debemos quedarnos en casa

# %%
#3
numeritos = [2, 5, 3, 7]

for numero in numeritos:
 print(numero + 2)
# Out:
# 4
# 7
# 5
# 9
