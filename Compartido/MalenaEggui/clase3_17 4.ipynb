# %%
import pandas

# %%
pandas.read_csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37364d1f7a87> in <cell line: 1>()
# ----> 1 pandas.read_csv
#
# NameError: name 'pandas' is not defined

# %%
pandas.read_csv("m06_ingresos-globales-ventas-musica-grabada-segmento.csv")
# Out:
#    indice_tiempo  ingresos_ventas_musica_streaming  \
# 0     2001-01-01                               NaN
# 1     2002-01-01                               NaN
# 2     2003-01-01                               NaN
# 3     2004-01-01                               NaN
# 4     2005-01-01                               0.1
# 5     2006-01-01                               0.1
# 6     2007-01-01                               0.2
# 7     2008-01-01                               0.3
# 8     2009-01-01                               0.4
# 9     2010-01-01                               0.4
# 10    2011-01-01                               0.6
# 11    2012-01-01                               1.0
# 12    2013-01-01                               1.4
# 13    2014-01-01                               1.9
# 14    2015-01-01                               2.8
# 15    2016-01-01                               4.6
# 16    2017-01-01                               6.5
# ...
