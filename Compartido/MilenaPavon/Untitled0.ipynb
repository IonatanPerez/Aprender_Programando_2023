# %%
# vamos importar una libreria
import pandas

# %%
arbolado = pandas.read_csv("arbolado-publico-lineal-2017-2018.csv")

# %%
arbolado.columns
# Out:
# Index(['long', 'lat', 'nro_registro', 'tipo_activ', 'comuna', 'manzana',
#        'calle_nombre', 'calle_altura', 'calle_chapa', 'direccion_normalizada',
#        'ubicacion', 'nombre_cientifico', 'ancho_acera', 'estado_plantera',
#        'ubicacion_plantera', 'nivel_plantera', 'diametro_altura_pecho',
#        'altura_arbol'],
#       dtype='object')

# %%
arbolado[arbolado[arbolado]]

# %%
arbolado
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'altura arbol'
#
# The above exception was the direct cause of the following exception:
#
# ...
