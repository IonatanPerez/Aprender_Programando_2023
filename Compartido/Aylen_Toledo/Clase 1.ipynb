# %%
print("hola mundo")
# Out:
# hola mundo

# %%
print("chau, me aburri")
# Out:
# chau, me aburri

# %%
2 * 4
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
4**0.5
# Out:
# 2.0

# %%
5/2
# Out:
# 2.5

# %%
10%3
# Out:
# 1

# %%
"hola"
# Out:
# 'hola'

# %%
numero1 = input()
numero1 = int(numero1)
numero2 = input()
numero2 = int(numero2)
resultado = numero1 + numero2
print (f"el resultado de sumar {numero1} mas {numero2} da: {resultado}")
# Out:
# 20
# 22
# el resultado de sumar 20 mas 22 da: 42
