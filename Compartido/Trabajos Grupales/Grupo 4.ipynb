# %% [markdown]
# # **Grupo 4 - Ciberseguridad**
# - *Belu Poma*
# - *Joaco Salto*
# - *Lauty Racedo*
# - *Lucho Martinez*

# %% [markdown]
# ### Temática concreta del proyecto:
# Aun no decidida.

# %% [markdown]
# ### Datos de interes:
# Español:
# https://es.statista.com/estadisticas/511908/sistemas-de-ciberseguridad-empleados-por-los-internautas-automatizables/
# https://fedinews.com/?_=%2Ftemas%2F3166%2Fciberdelitos-en-espana%2F%23KJWqMdlUlBnuOKMGRBz0jpjhec9jFFI%3D
# https://es.statista.com/estadisticas/1130614/aplicaciones-de-ai-en-ciberseguridad-de-empresas/
# Ingles:
# https://www.kaggle.com/katehighnam/beth-dataset/code
# https://ieee-dataport.org/open-access/dataset-cyber-attacks-honeyselk
# https://www.searchlogistics.com/learn/statistics/cybersecurity-statistics/
# https://www.kaggle.com/datasets/zulanac/fake-and-real-news
#
#
# Aca encontre algo:
# https://datasetsearch.research.google.com/search?src=0&query=cyber%20attacks&docid=L2cvMTFyZ20zeXQwZg%3D%3D

# %% [markdown]
# **CODIGO**

# %%
import pandas as pd

agua1 = pd.read_csv("test_dataset.csv")
agua2 = pd.read_csv("training_dataset_1.csv")
#agua3 = pd.read_csv("training_dataset_2.csv")

# %%
agua3
# Out:
#          DATETIME  L_T1  L_T2  L_T3  L_T4  L_T5  L_T6  L_T7   F_PU1  S_PU1  \
# 0     04/07/16 00  2.44  5.24  3.19  4.10  2.86  5.50  4.39   93.63      1
# 1     04/07/16 01  2.66  4.53  3.20  4.18  3.29  5.44  4.53   89.41      1
# 2     04/07/16 02  3.11  3.66  3.66  4.21  3.87  5.15  3.22   89.88      1
# 3     04/07/16 03  3.62  3.04  4.17  4.04  3.56  4.98  2.40   88.10      1
# 4     04/07/16 04  4.08  2.68  4.73  3.20  3.11  5.39  3.46   87.01      1
# ...           ...   ...   ...   ...   ...   ...   ...   ...     ...    ...
# 4172  24/12/16 20  2.65  2.37  3.85  3.04  3.82  4.94  2.19  120.08      1
# 4173  24/12/16 21  2.24  2.56  3.42  2.92  3.69  5.02  1.97  119.12      1
# 4174  24/12/16 22  1.91  2.76  2.95  2.49  2.70  5.14  1.87  120.71      1
# 4175  24/12/16 23  1.52  2.52  3.33  2.03  1.69  5.10  1.39  120.02      1
# 4176  25/12/16 00  1.10  2.12  3.73  2.73  1.58  5.13  1.19  120.33      1
#
# ...
