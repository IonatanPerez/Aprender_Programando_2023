# %% [markdown]
# # **Grupo 5 - Educación**

# %% [markdown]
# # Integrantes
# - *Aylen Nerea Toledo*
# - *Milena Pavon*
# - *Gian Cusi*
# - *Sol Mizrahi*
# - *Joaco Salto*
# - *Lauty Racedo*

# %% [markdown]
# # Tematica a trabajar
# NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
encuesta2012 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2012.csv", encoding='latin-1')
encuesta2013 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2013.csv", encoding='latin-1')
encuesta2014 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2014.csv", encoding='latin-1')
encuesta2015 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2015.csv", encoding='latin-1')
encuesta2016 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2016.csv", encoding='latin-1')
encuesta2017 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2017.csv", encoding='latin-1')
encuesta2018 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2018.csv", encoding='latin-1')
encuesta2019 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2019.csv", encoding='latin-1')

encuesta2012['año_encuesta'] = 2012
encuesta2 ño_encuesta'] = 2014
encuesta2015['año_encuesta'] = 2015
encuesta2016['año_encuesta'] = 2016
encuesta2017['año_encuesta'] = 2017
encuesta2018['año_encuesta'] = 2018
encuesta2019['año_encuesta'] = 2019

encuesta2012.columns = encuesta2019.columns
encuesta2013.columns = encuesta2019.columns
encuesta2014.columns = encuesta2019.columns
encuesta2015.columns = encuesta2019.columns
encuesta2016.columns = encuesta2019.columns
encuesta2017.columns = encuesta2019.columns
encuesta2018.columns = encuesta2019.columns

encuesta_total = pd.concat([encuesta2012, encuesta2013, encuesta2014, encuesta2015, encuesta2016, encuesta2017, encuesta2018, encuesta2019])

# %%
encuesta_total
# Out:
#          id  nhogar  miembro  comuna             dominio  edad   sexo  \
# 0         1       1        1       1  Resto de la Ciudad    69  Mujer
# 1         1       1        2       1  Resto de la Ciudad    19  Mujer
# 2         2       1        1       1  Resto de la Ciudad    56  Varon
# 3         3       1        1       1  Resto de la Ciudad    50  Mujer
# 4         3       1        2       1  Resto de la Ciudad    75  Mujer
# ...     ...     ...      ...     ...                 ...   ...    ...
# 14314  5794       1        1      10  Resto de la Ciudad    99  Varon
# 14315  5794       1        2      10  Resto de la Ciudad    78  Mujer
# 14316  5794       1        3      10  Resto de la Ciudad    60  Mujer
# 14317  5794       1        4      10  Resto de la Ciudad    92  Mujer
# 14318  5795       1        1       2  Resto de la Ciudad   100  Mujer
#
#             parentesco_jefe                 situacion_conyugal  \
# ...

# %%
encuesta2019.shape
# Out:
# (14319, 32)

# %%
for col1, col2 in zip(encuesta2018.columns, encuesta2019.columns,):
  print (col1==col2)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
encuesta_total.columns
# Out:
# Index(['id', 'nhogar', 'miembro', 'comuna', 'dominio', 'edad', 'sexo',
#        'parentesco_jefe', 'situacion_conyugal', 'num_miembro_padre',
#        'num_miembro_madre', 'estado_ocupacional', 'cat_ocupacional',
#        'calidad_ingresos_lab', 'ingreso_total_lab', 'calidad_ingresos_no_lab',
#        'ingreso_total_no_lab', 'calidad_ingresos_totales', 'ingresos_totales',
#        'calidad_ingresos_familiares', 'ingresos_familiares',
#        'ingreso_per_capita_familiar', 'estado_educativo', 'sector_educativo',
#        'nivel_actual', 'nivel_max_educativo', 'años_escolaridad',
#        'lugar_nacimiento', 'afiliacion_salud', 'hijos_nacidos_vivos',
#        'cantidad_hijos_nac_vivos', 'año_encuesta'],
#       dtype='object')

# %%
encuesta_total['sexo'].unique()
# Out:
# array(['Mujer', 'Varon'], dtype=object)

# %%
encuesta_total['afiliacion_salud'].unique()
# Out:
# array(['Solo prepaga o mutual via OS', 'Solo obra social',
#        'Solo sistema publico', 'Otros',
#        'Solo plan de medicina prepaga por contrataciÃ³n voluntaria', nan,
#        'Solo plan de medicina prepaga por contratación voluntaria'],
#       dtype=object)

# %%
data = encuesta_total

# %%
data.groupby(['sexo','afiliacion_salud'])['id'].count().reset_index()
# Out:
#      sexo                                   afiliacion_salud     id
# 0   Mujer                                              Otros   4505
# 1   Mujer                                   Solo obra social  28761
# 2   Mujer  Solo plan de medicina prepaga por contrataciÃ³...   4097
# 3   Mujer  Solo plan de medicina prepaga por contratación...   1366
# 4   Mujer                       Solo prepaga o mutual via OS  10304
# 5   Mujer                               Solo sistema publico  14005
# 6   Varon                                              Otros   2969
# 7   Varon                                   Solo obra social  24882
# 8   Varon  Solo plan de medicina prepaga por contrataciÃ³...   3623
# 9   Varon  Solo plan de medicina prepaga por contratación...   1282
# 10  Varon                       Solo prepaga o mutual via OS   9163
# 11  Varon                               Solo sistema publico  13015

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of          id  nhogar  miembro  comuna             dominio  edad   sexo  \
# 0         1       1        1       5  Resto de la Ciudad    18  Mujer
# 1         1       1        2       5  Resto de la Ciudad    18  Mujer
# 2         2       1        1       2  Resto de la Ciudad    18  Varon
# 3         2       1        2       2  Resto de la Ciudad    50  Mujer
# 4         2       1        3       2  Resto de la Ciudad    17  Varon
# ...     ...     ...      ...     ...                 ...   ...    ...
# 14314  5794       1        1      10  Resto de la Ciudad    99  Varon
# 14315  5794       1        2      10  Resto de la Ciudad    78  Mujer
# 14316  5794       1        3      10  Resto de la Ciudad    60  Mujer
# 14317  5794       1        4      10  Resto de la Ciudad    92  Mujer
# 14318  5795       1        1       2  Resto de la Ciudad   100  Mujer
#
#             parentesco_jefe                situacion_conyugal  \
# ...

# %%
sns.barplot(data=data, y="estado_educativo", x="edad")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad68684125b0> in <cell line: 1>()
# ----> 1 sns.barplot(data=data, y="afiliacion_salud", x="edad")
#
# NameError: name 'sns' is not defined

# %%
sns.barplot(data=encuesta_total, y="nivel_max_educativo", x="comuna")
# Out:
# <Axes: xlabel='comuna', ylabel='nivel_max_educativo'>

# %%
sns.barplot(data=encuesta_total, y="lugar_nacimiento", x="ingreso_total_no_lab")
# Out:
# <Axes: xlabel='ingreso_total_no_lab', ylabel='lugar_nacimiento'>

# %%
sns.histplot(data=encuesta2019, y="estado_educativo", x="edad")
# Out:
# <Axes: xlabel='edad', ylabel='estado_educativo'>

# %%
sns.histplot(data=encuesta2019, y="afiliacion_salud", x="edad")
# Out:
# <Axes: xlabel='edad', ylabel='afiliacion_salud'>

# %%
sns.histplot(data=encuesta2019, y="situacion_conyugal", x="comuna")
# Out:
# <Axes: xlabel='comuna', ylabel='situacion_conyugal'>

# %%
sns.histplot(data=encuesta2019, y="situacion_conyugal", x="edad")
# Out:
# <Axes: xlabel='edad', ylabel='situacion_conyugal'>

# %% [markdown]
# **1. Nivel educativo.**

# %%
sns.barplot(data=encuesta2019, y="nivel_actual", x="edad")
# Out:
# <Axes: xlabel='edad', ylabel='nivel_actual'>

# %%
sns.barplot(data=encuesta_total, x="comuna", y="nivel_max_educativo")
# Out:
# <Axes: xlabel='comuna', ylabel='nivel_max_educativo'>

# %%
sns.scatterplot(data=encuesta2019, y="nivel_actual", x="lugar_nacimiento")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()
# Out:
# <ipython-input-72-2931f8aefb9d>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
sns.histplot(data=encuesta2019, y="nivel_max_educativo", x="lugar_nacimiento")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()
# Out:
# <ipython-input-13-5af152c867d6>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# **2. Ingresos.**

# %%
Ingreso = encuesta2019.sort_values(by="ingresos_totales")
Ingresomalto = Ingreso[Ingreso["ingresos_totales"] > 183000]
Ingresolab = encuesta2019.sort_values(by="ingreso_total_lab")
Ingresomaltolab = Ingreso[Ingreso["ingreso_total_lab"] > 150000]
Ingresonolab = encuesta2019.sort_values(by="ingreso_total_no_lab")
Ingresomaltonolab = Ingreso[Ingreso["ingreso_total_no_lab"] > 82000]

# %%
sns.barplot(data=Ingresomalto, x="sexo", y="ingreso_total_lab")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=Ingresomalto, x="edad", y="ingresos_totales")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=Ingresomaltolab, x="edad", y="ingreso_total_lab")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=Ingresomaltonolab, x="edad", y="ingreso_total_no_lab")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=encuesta2019, x="lugar_nacimiento", y="ingresos_totales")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=encuesta2019, x="lugar_nacimiento", y="ingreso_total_lab")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=encuesta2019, x="lugar_nacimiento", y="ingreso_total_no_lab")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=encuesta2019, x="comuna", y="ingreso_total_lab")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=encuesta2019, x="comuna", y="ingreso_total_no_lab")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=encuesta2019, x="comuna", y="ingresos_totales")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.barplot(data=encuesta_total, y="sexo", x="ingreso_total_lab")
# Out:
# <Axes: xlabel='ingreso_total_lab', ylabel='sexo'>

# %%
sns.barplot(data=encuesta_total, y="sexo", x="ingreso_total_no_lab")
# Out:
# <Axes: xlabel='ingreso_total_no_lab', ylabel='sexo'>

# %%
sns.barplot(data=encuesta_total, y="sexo", x="ingresos_totales")
# Out:
# <Axes: xlabel='ingresos_totales', ylabel='sexo'>

# %%
sns.countplot(data=encuesta2019, x="situacion_conyugal")
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.countplot(data=encuesta_total, x="estado_ocupacional")
# Out:
# <Axes: xlabel='estado_ocupacional', ylabel='count'>

# %%
sns.barplot(data=encuesta_total, x="edad", y="estado_ocupacional")
# Out:
# <Axes: xlabel='edad', ylabel='estado_ocupacional'>

# %% [markdown]
# **3. Situación conyugal y cantidad de hijos.**

# %%
sns.barplot(data=encuesta_total, x="comuna", y="cat_ocupacional")
# Out:
# <Axes: xlabel='comuna', ylabel='cat_ocupacional'>
