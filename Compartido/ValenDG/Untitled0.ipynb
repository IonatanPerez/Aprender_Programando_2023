# %%
import pandas as pd

# %%
datos = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/sbase/bocas-subte/bocas-de-subte.csv")

# %%
datos.head(30)
# Out:
#          long        lat  id linea                            estacion  \
# 0  -58.384068 -34.602106   1     D           TRIBUNALES - TEATRO COLÓN
# 1  -58.384372 -34.602394   2     D           TRIBUNALES - TEATRO COLÓN
# 2  -58.397250 -34.587804   3     H                           LAS HERAS
# 3  -58.403967 -34.598733   4     H                             CÓRDOBA
# 4  -58.405406 -34.603884   5     H                          CORRIENTES
# 5  -58.405237 -34.604170   6     H                          CORRIENTES
# 6  -58.405087 -34.603550   7     H                          CORRIENTES
# 7  -58.405312 -34.603501   8     H                          CORRIENTES
# 8  -58.405352 -34.603678   9     H                          CORRIENTES
# 9  -58.397386 -34.623075  10     E                           PICHINCHA
# 10 -58.397035 -34.623028  11     E                           PICHINCHA
# 11 -58.397338 -34.623276  12     E                           PICHINCHA
# ...

# %%
### CLASE 0-1 ###
materias = ["BioFisica","QuimicaUltraAvanzada", "Algebra vectorial"]
seleccion = materias[0]
materias.append("Filosofia") 
materias.remove("BioFisica") #materias.remove(materias[0])
materias
# Out:
# ['QuimicaUltraAvanzada', 'Algebra vectorial', 'Filosofia']

# %%
#Clase 2# Estructura condicional
num1,num2 = input("Verifique similitud"),input("Verifique similitud")
if num1 == num2:
  print("Son iguales")

nubes = "No LLueve"
if nubes == "No llueve":
  print("Podemos ir a la plaza")
else:
  "debemos quedarnos en casa"

lista = [i for i in range(3)]
for i in lista:
  print(i)

def division_insegura():
  print(input(float("División")) / float(input("División")) )

def division_segura():
  div1,div2 = input("Division"),input("Division")
  if div2==0:
    return "no se puede realizar esta operación"
  else:
    return div1/div2
# Out:
# 1
# 2
