# %%
import pandas as pd

# %%
#ARBOLADO
data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <ipython-input-19-60fe6fd70a17>:2: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")

# %%
#MURALES
datos = pd.read_csv("murales.csv", sep=";")
datos
# Out:
#      Unnamed: 0                                          WKT  \
# 0             0  POINT (-58.3843530922336 -34.5975348140559)
# 1             1  POINT (-58.3741921638092 -34.6116201690093)
# 2             2  POINT (-58.3851629076421 -34.6123693095443)
# 3             3  POINT (-58.3851629076421 -34.6123693095443)
# 4             4  POINT (-58.3851629076421 -34.6123693095443)
# ..          ...                                          ...
# 416         416  POINT (-58.3683360886899 -34.6367215700058)
# 417         417  POINT (-58.3745373662307 -34.6160871174382)
# 418         418  POINT (-58.3624010018425 -34.6344979603594)
# 419         419  POINT (-58.3702746686521 -34.6166043000222)
# 420         420  POINT (-58.4015672772429 -34.6390533212159)
#
#                                   NOMBRE                          CARACT_SIT  \
# 0                         MATER GALECIAE               GALERIA LAS VICTORIAS
# ...

# %%
### CLASE 0-1 ###
materias = ["BioFisica","QuimicaUltraAvanzada", "Algebra vectorial"]
seleccion = materias[0]
materias.append("Filosofia")
materias.remove("BioFisica") #materias.remove(materias[0])
materias
# Out:
# ['QuimicaUltraAvanzada', 'Algebra vectorial', 'Filosofia']

# %%
#Clase 2# Estructura condicional
num1,num2 = input("Verifique similitud"),input("Verifique similitud")
if num1 == num2:
  print("Son iguales")

nubes = "No LLueve"
if nubes == "No llueve":
  print("Podemos ir a la plaza")
else:
  "debemos quedarnos en casa"

lista = [i for i in range(3)]
for i in lista:
  print(i)

def division_insegura():
  print(input(float("División")) / float(input("División")) )

def division_segura():
  div1,div2 = input("Division"),input("Division")
  if div2==0:
    return "no se puede realizar esta operación"
  else:
    return div1/div2
# Out:
# 1
# 2

# %%
#Clase 3#Introduccion a pandas
datos.iloc[[i+datos.shape[0]-3 for i in range(3)]]
print(datos.columns)
datos.AUTORES.value_counts()
datos.drop(columns=["TAMAÑO_TS"])
datos.columns = [str(i).lower() for i in datos.columns]
# Out:
# Index(['Unnamed: 0', 'WKT', 'NOMBRE', 'CARACT_SIT', 'AUTORES', 'TECNICA',
#        'F_E', 'TAMAÑO_TS', 'UBICACION', 'DIRECCION', 'DOM_ORIG', 'CALLE',
#        'ALTURA', 'BARRIO', 'COMUNA'],
#       dtype='object')

# %%
#Clase 4 #pandas filtros
datos[datos["F_E"]== 1939]

datos[datos["AUTORES"]=="LUIS SEOANE"]
datos[datos["AUTORES"]=="LUIS SEOANE"].value_counts()

datos[datos["TECNICA"]!= "MURAL CERAMICO"]

datos[datos["TECNICA"]!= "OLEO SOBRE SOPORTE RIGIDO"]

datos["AUTORES"].value_counts()
datos[datos["AUTORES"]=="BENITO QUINQUELA MARTIN"]
# Out:
#      Unnamed: 0                                          WKT  \
# 45           45  POINT (-58.3924764989853 -34.5831089038315)
# 46           46  POINT (-58.3941720635806 -34.5974348113392)
# 121         121  POINT (-58.4252545646581 -34.5786634442563)
# 142         142  POINT (-58.3606751590047 -34.6388602918762)
# 166         166  POINT (-58.3598648394233 -34.6387874339039)
# 167         167   POINT (-58.3603025791975 -34.638981239287)
# 171         171  POINT (-58.3763716876341 -34.6087019330975)
# 183         183   POINT (-58.381388949827 -34.6122069769358)
# 187         187   POINT (-58.368983122084 -34.5840029596311)
# 232         232  POINT (-58.3606751590047 -34.6388602918762)
# 233         233  POINT (-58.3606751590047 -34.6388602918762)
# 234         234  POINT (-58.3606751590047 -34.6388602918762)
# 235         235  POINT (-58.3606751590047 -34.6388602918762)
# 236         236  POINT (-58.3606751590047 -34.6388602918762)
# ...

# %%
#Clase 5 #Visualizaciones
sns.countplot(data=data, x='comuna', hue='nombre_cientifico')
# Out:
# <Axes: xlabel='comuna', ylabel='count'>

# %%
sns.scatterplot(data=data, x="altura_arbol", y="diametro_altura_pecho")
# Out:
# <Axes: xlabel='altura_arbol', ylabel='diametro_altura_pecho'>

# %%
sns.barplot(data=data, x="comuna", y="diametro_altura_pecho")
# Out:
# <Axes: xlabel='comuna', ylabel='diametro_altura_pecho'>

# %%
data_edit = data["calle_nombre"].value_counts()
#Del Libertador, Av
data_edit = data[data["calle_nombre"] == "Del Libertador, Av" ]
sns.displot(data=data_edit, x="altura_arbol",y="diametro_altura_pecho")
# Out:
#              long        lat nro_registro tipo_activ  comuna manzana  \
# 518    -58.379661 -34.590146        52199     Lineal       1     NaN
# 519    -58.379661 -34.590146        52200     Lineal       1     NaN
# 520    -58.374144 -34.593659        52201     Lineal       1     NaN
# 521    -58.380415 -34.589736        52202     Lineal       1     NaN
# 522    -58.380415 -34.589736        52203     Lineal       1     NaN
# ...           ...        ...          ...        ...     ...     ...
# 367720 -58.423058 -34.571056       154170     Lineal      14     NaN
# 367721 -58.423058 -34.571056       154171     Lineal      14     NaN
# 367722 -58.423058 -34.571056       154172     Lineal      14     NaN
# 367814 -58.421779 -34.572065       161806     Lineal      14     NaN
# 367898 -58.421779 -34.572065       163790     Lineal      14     NaN
#
#               calle_nombre calle_altura calle_chapa   direccion_normalizada  \
# ...
