# %% [markdown]
# #Desafio 1
# ##Listas
# - 1) hacer una lista que contenga 3 materias de la escuela
# - 2) Eliminar el primer registro de la lista
# - 3) Agregar una materia mas al final
# - 4) Seleccionar el segundo elemento de la lista

# %%
Lista_de_materias=["Biología","Matemática","Lenguaje"]

# %%
Lista_de_materias.remove ("Biología")

# %%
Lista_de_materias.pop (0)
# Out:
# 'Biología'

# %%
Lista_de_materias.append ("Física")

# %%
Lista_de_materias [1]
# Out:
# 'Lenguaje'
