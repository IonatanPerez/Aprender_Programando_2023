# %%
materias = ["Lengua", "Matemáticas", "Biología"]

# %%
materias.remove ("Lengua")
print (materias)
# Out:
# ['Matemáticas', 'Biología']

# %%
materias = ["Lengua", "Matemáticas", "Biología"]
materias.append ("Física")

# %%
materias
# Out:
# ['Lengua', 'Matemáticas', 'Biología', 'Física']
