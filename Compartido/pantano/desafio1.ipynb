# %% [markdown]
# # *Desafío 1*

# %%
# 1.
materias = []
materia_nueva = ""
print ("Introduce 3 materias de tu escuela:")
while len(materias) < 3:
  print("Escribe una materia:")
  materia_nueva = input()
  materias.append(materia_nueva)
# 2.
print (f"Tu segunda materia es {materias[1]}.")
# 3.
print ("Ahora agrega otra materia.")
materia_nueva = input()
materias.append(materia_nueva)
print (f"La ultima materia que agregaste es {materias[3]}.")
# 4.
materias.pop(0)
print ("He eliminado el primer elemento de la lista. Ahora la lista es la siguiente:")
print (materias)
# Out:
# Introduce 3 materias de tu escuela:
# Escribe una materia:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6787d17c2f0d> in <cell line: 5>()
#       5 while len(materias) < 3:
#       6   print("Escribe una materia:")
# ----> 7   materia_nueva = input()
#       8   materias.append(materia_nueva)
#       9 # 2.
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...
