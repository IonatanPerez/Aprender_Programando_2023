# %% [markdown]
# # *Desafío 3*

# %%
# 0.
import pandas as pd
data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-cultura/murales/murales.csv", sep=";")

# %%
# 1.
data.tail(3)
# Out:
#      Unnamed: 0                                          WKT  \
# 418         418  POINT (-58.3624010018425 -34.6344979603594)
# 419         419  POINT (-58.3702746686521 -34.6166043000222)
# 420         420  POINT (-58.4015672772429 -34.6390533212159)
#
#                  NOMBRE CARACT_SIT                            AUTORES  \
# 418            CAMINITO        NaN                     VINCENT WALTER
# 419  TITULO DESCONOCIDO    FACHADA          GIAMPIETRO / JAIME / NOLA
# 420       ESCENA URBANA    FACHADA  GRUPO MURALISTA DE RICARDO VILLAR
#
#                               TECNICA     F_E TAMAÑO_TS             UBICACION  \
# 418  ALTORELIEVE EN CEMENTO COLOREADO  1989.0     3 X 2               FACHADA
# 419                     PINTURA MURAL  1995.0    15 X 2  MURO LINEA MUNICIPAL
# 420                     PINTURA MURAL  1996.0       740               FACHADA
#
#                   DIRECCION                DOM_ORIG        CALLE  ALTURA  \
# ...

# %%
# 2.
data.columns
# Out:
# Index(['Unnamed: 0', 'WKT', 'NOMBRE', 'CARACT_SIT', 'AUTORES', 'TECNICA',
#        'F_E', 'TAMAÑO_TS', 'UBICACION', 'DIRECCION', 'DOM_ORIG', 'CALLE',
#        'ALTURA', 'BARRIO', 'COMUNA'],
#       dtype='object')

# %%
# 3.
data["AUTORES"]
# Out:
# 0                            LUIS SEOANE
# 1                      ARQ. CARLOS MORRA
# 2                      AUTOR DESCONOCIDO
# 3                      AUTOR DESCONOCIDO
# 4                      AUTOR DESCONOCIDO
#                      ...
# 416                       VINCENT WALTER
# 417                                  NaN
# 418                       VINCENT WALTER
# 419            GIAMPIETRO / JAIME / NOLA
# 420    GRUPO MURALISTA DE RICARDO VILLAR
# Name: AUTORES, Length: 421, dtype: object

# %%
# 4.
data["F_E"].replace("0.0", pd.NA, inplace = True)
data["F_E"].min
data[data["F_E"] == 1901]
# Out:
#      Unnamed: 0                                          WKT      NOMBRE  \
# 1             1  POINT (-58.3741921638092 -34.6116201690093)  SIN TITULO
# 273         273  POINT (-58.3731118549293 -34.6078141791827)   SAN SIMON
# 274         274  POINT (-58.3731118549293 -34.6078141791827)   SAN TADEO
#
#                              CARACT_SIT                 AUTORES  \
# 1    CASA NAC.DE LA MUSICA,EX BIBL.NAC.       ARQ. CARLOS MORRA
# 273              CATEDRAL METROPOLITANA  FRANCISCO PAOLO PARISI
# 274              CATEDRAL METROPOLITANA  FRANCISCO PAOLO PARISI
#
#                       TECNICA     F_E TAMAÑO_TS           UBICACION  \
# 1          VITRAUX  CLARABOYA  1901.0       S/M  EX SALA DE LECTURA
# 273  PINTURA MURALAL ENCAUSTO  1901.0       S/M         NAVECENTRAL
# 274  PINTURA MURALAL ENCAUSTO  1901.0       S/M         NAVECENTRAL
#
#              DIRECCION         DOM_ORIG          CALLE  ALTURA       BARRIO  \
# ...

# %%
# 5.
del data['TAMAÑO_TS']
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TAMAÑO_TS'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# 6.
data.columns = ["unnamed: 0", "wkt", "nombre", "caract_sit", "autores", "tecnica", "f_e", "ubicacion", "direccion", "dom_orig", "calle", "altura", "barrio", "comuna"]
data
# Out:
#      unnamed: 0                                          wkt  \
# 0             0  POINT (-58.3843530922336 -34.5975348140559)
# 1             1  POINT (-58.3741921638092 -34.6116201690093)
# 2             2  POINT (-58.3851629076421 -34.6123693095443)
# 3             3  POINT (-58.3851629076421 -34.6123693095443)
# 4             4  POINT (-58.3851629076421 -34.6123693095443)
# ..          ...                                          ...
# 416         416  POINT (-58.3683360886899 -34.6367215700058)
# 417         417  POINT (-58.3745373662307 -34.6160871174382)
# 418         418  POINT (-58.3624010018425 -34.6344979603594)
# 419         419  POINT (-58.3702746686521 -34.6166043000222)
# 420         420  POINT (-58.4015672772429 -34.6390533212159)
#
#                                   nombre                          caract_sit  \
# 0                         MATER GALECIAE               GALERIA LAS VICTORIAS
# ...
