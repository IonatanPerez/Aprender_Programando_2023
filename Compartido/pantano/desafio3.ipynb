# %% [markdown]
# # *Desafío 3*

# %%
# 0.
import pandas as pd
data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-cultura/murales/murales.csv", sep=";")

# %%
# 1.
data.tail(3)

# %%
# 2.
data.columns
# Out:
# Index(['Unnamed: 0', 'WKT', 'NOMBRE', 'CARACT_SIT', 'AUTORES', 'TECNICA',
#        'F_E', 'TAMAÑO_TS', 'UBICACION', 'DIRECCION', 'DOM_ORIG', 'CALLE',
#        'ALTURA', 'BARRIO', 'COMUNA'],
#       dtype='object')

# %%
# 3.
data["AUTORES"]
# Out:
# 0                            LUIS SEOANE
# 1                      ARQ. CARLOS MORRA
# 2                      AUTOR DESCONOCIDO
# 3                      AUTOR DESCONOCIDO
# 4                      AUTOR DESCONOCIDO
#                      ...
# 416                       VINCENT WALTER
# 417                                  NaN
# 418                       VINCENT WALTER
# 419            GIAMPIETRO / JAIME / NOLA
# 420    GRUPO MURALISTA DE RICARDO VILLAR
# Name: AUTORES, Length: 421, dtype: object

# %%
# 4.
data["F_E"].min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-90374de89d14> in <cell line: 2>()
#       1 # 4.
# ----> 2 data["F_E"].min(5)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in min(self, axis, skipna, level, numeric_only, **kwargs)
#   11963             **kwargs,
#   11964         ):
# > 11965             return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11966
#   11967         setattr(cls, "min", min)
#
# ...
