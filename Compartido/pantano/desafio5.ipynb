# %% [markdown]
# # *Desafío 5*

# %%
# 0.
import pandas as pd
data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <ipython-input-1-bed2257ad1b2>:3: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")

# %%
# 1.
Tipuana = data[(data["nombre_cientifico"] == "Tipuana tipu")]
sns.countplot(data=Tipuana, x="comuna")
# Out:
# <Axes: xlabel='comuna', ylabel='count'>

# %%
# 2.
# Dudo esta sea la columna destinada a representar el ancho, pero "ancho_acera" tampoco parecía serlo, y al no encontrar otra, pues, en mi ignorancia, elegí esta.
sns.barplot(data=data, x="comuna", y="diametro_altura_pecho")
# Out:
# <Axes: xlabel='comuna', ylabel='diametro_altura_pecho'>

# %%
# 3.
sns.distplot(data["diametro_altura_pecho"])
# Out:
# <ipython-input-11-b23bd9a3927c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["diametro_altura_pecho"])
# <Axes: xlabel='diametro_altura_pecho', ylabel='Density'>

# %%
# 4.
data["calle_nombre"].value_counts().sort_values(ascending=False)
streetmostrees = data[data["calle_nombre"] == "Del Libertador, Av"]
sns.displot(data=streetmostrees, x="altura_arbol", y="diametro_altura_pecho")
