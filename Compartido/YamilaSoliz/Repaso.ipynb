# %%
print("hola mundo :D")
# Out:
# hola mundo :D

# %%
# esto no se ejecuta 
print(3+5) #esto toma lo que esta dentro del parentesis como numeros pero si ponemos 
print("3+5") #esto toma lo que esta dentro del texto como texto por las comillas
# Out:
# 8
# 3+5

# %%
print (resultado)
# Out:
# 8

# %%
#Tenemos variables tipo numericas
numero1=3 # Esto es una variable entera
numero2= 3.0 #esto es un float
#tenemos variables tipo string
texto1= "Esto es un texto"

# %%
#Vamos a pedirle al ususario que introduxca un nombre
nombre = input()
print("La ultima letra de tu nombre es:")
print (nombre[5]) #si pongo -1 es la ultima letra y si pongo -2 es la anteultima
# Out:
# yamila
# La ultima letra de tu nombre es:
# a

# %%
#vamos a pedir que nos diga que tan largo es nuestro nombre
print("ingrese su nombre")
nombre = input()
print ("la cantidad de letras que tiene su nombre es")
print (len(nombre))
# Out:
# ingrese su nombre
# yamila
# la cantidad de letras que tiene su nombre es
# 6

# %%
nombres = ["isabella", "Daniela", "Luciano", "Joaquin", "Milena"]
print ("elija a la persona que quiera seleccionar")
seleccion = input()
seleccion = int(seleccion)
if seleccion > len(nombres)
print(f"El nombre seleccionado es {nombres[ ]})
# Out:
#   File "<ipython-input-30-dbb5673bfb8b>", line 5
#     if seleccion > len(nombres)
#                                ^
# SyntaxError: invalid syntax

# %%
#queremos hacer un progama que me diga si el numero que ingreso mayor o menos que diez
numero_ingresado = input()
numero_ingresado = int(numero_ingresado)

if numero_ingresado > 10:
  print (f"El numero {numero_ingresado} es mayor que 10")
else:
  if numero_ingresado <10:
  print(f"el numero {numero_ingresado} es menor o igual que 10")
  else:
    print(f"El numero {numero_ingresado} es igual a 10")
print ("Fin!")
# Out:
#   File "<ipython-input-27-4504bd73c405>", line 9
#     print(f"el numero {numero_ingresado} es menor o igual que 10")
#     ^
# IndentationError: expected an indented block
