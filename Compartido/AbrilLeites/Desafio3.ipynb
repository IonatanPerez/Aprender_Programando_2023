# %%
# vamos a ver como abrir un archivo con datos en python
# archivo csv= cada columna esta separada por una coma o punto y coma

# %%
#vamos a importar una libreria
import pandas

# %%
murales = pandas.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-cultura/murales/murales.csv", sep=";")

# %%
murales.tail(3)
# Out:
#      Unnamed: 0                                          WKT  \
# 418         418  POINT (-58.3624010018425 -34.6344979603594)
# 419         419  POINT (-58.3702746686521 -34.6166043000222)
# 420         420  POINT (-58.4015672772429 -34.6390533212159)
#
#                  NOMBRE CARACT_SIT                            AUTORES  \
# 418            CAMINITO        NaN                     VINCENT WALTER
# 419  TITULO DESCONOCIDO    FACHADA          GIAMPIETRO / JAIME / NOLA
# 420       ESCENA URBANA    FACHADA  GRUPO MURALISTA DE RICARDO VILLAR
#
#                               TECNICA     F_E TAMAÑO_TS             UBICACION  \
# 418  ALTORELIEVE EN CEMENTO COLOREADO  1989.0     3 X 2               FACHADA
# 419                     PINTURA MURAL  1995.0    15 X 2  MURO LINEA MUNICIPAL
# 420                     PINTURA MURAL  1996.0       740               FACHADA
#
#                   DIRECCION                DOM_ORIG        CALLE  ALTURA  \
# ...

# %%
murales.columns
# Out:
# Index(['Unnamed: 0', 'WKT', 'NOMBRE', 'CARACT_SIT', 'AUTORES', 'TECNICA',
#        'F_E', 'TAMAÑO_TS', 'UBICACION', 'DIRECCION', 'DOM_ORIG', 'CALLE',
#        'ALTURA', 'BARRIO', 'COMUNA'],
#       dtype='object')

# %%
murales["AUTORES"].value_counts()
# Out:
# BENITO QUINQUELA MARTIN              41
# LUIS SEOANE                          18
# RAUL SOLDI                           11
# MARTIN S. NOEL - MANUEL ESCASANY     10
# JUAN CARLOS CASTAGNINO               10
#                                      ..
# EDELMIRO LESCANO CEBALLOS             1
# PAULINA BLINDER                       1
# BENITPO QUINQUELA MARTIN              1
# MONICA CORRALES                       1
# GRUPO MURALISTA DE RICARDO VILLAR     1
# Name: AUTORES, Length: 213, dtype: int64

# %%
murales["F_E"].mean()
# Out:
# 1913.273159144893
