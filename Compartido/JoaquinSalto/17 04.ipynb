# %%
#Importamos una libreria
import pandas as pd
import matplotlib.pyplot as plt


bocas_subte = pd.read_csv("/content/drive/MyDrive/Programacion/bocas-de-subte.csv")

#bocas_subte # Muestra los primeros 5 y los últimos 5 registros
#bocas_subte.head(3) # Muestra los primeros
#bocas_subte.tail(3) # Muestra los ultimos
#bocas_subte.shape # Devuelve el tamaño del dataset
#bocas_subte.sample() # Muestra registros aleatoriamente
#bocas_subte['linea'] # Muestra la todo lo de la columna deseada
#bocas_subte.linea # Muestra la todo lo de la columna deseada
#bocas_subte['linea'].value_counts() # Suma todos los valores de la columna deseada
#bocas_subte.columns # Te da una lista de las columnas que hay
#bocas_subte.dtypes # Tipo de dato de cada columna
#bocas_subte['comuna'].value_counts() # Cuantas bocas de subta hay por comuna
#bocas_subte[['linea','lat']] # Para ver más de una columna se debe armar una lista de columnas que deseo seleccionar
#bocas_subte.info() # Devuelve un resumen de información general del dataset
#bocas_subte["id"].count() # Cuenta cuantas bocas de subte hay
#bocas_subte['altura'].sum() # Cuánto es la altura sumada
#bocas_subte['altura'].max # Cuál es la altura mas alta
#bocas_subte['altura'].min # Cuál es la altura más baja
# .mean # Promedio
#bocas_subte['linea'].unique() # Para conocer los valores únicos que toma una column
#bocas_subte['estacion'].value_counts() # Para conocer cuantos registros(filas) hay de cada valor de una columna
#bocas_subte.rename(columns={"long":"logitud"}, inplace=True) # Reemplaza el nombre de una columna por otro # El argumento inplace indica que se haga la modificación en el mismo DataFrame que estamos utilizando, otra posiblidad sería crear un DataFrame nuevo
#bocas_subte.drop(columns="rampa", inplace=True) # Elimina una columna





#plt.scatter(bocas_subte['long'], bocas_subte['lat'], color='orange') # Grafico
# Out:
# Index(['long', 'lat', 'id', 'linea', 'estacion', 'numero_de_', 'destino_bo',
#        'lineas_de_', 'cierra_fin', 'escalera_p', 'escalera_m', 'ascensor',
#        'salvaescal', 'calle', 'altura', 'calle2', 'barrio', 'comuna',
#        'observacio', 'Objeto', 'dom_norma', 'dom_orig'],
#       dtype='object')

# %%
#Importamos una libreria
import pandas as pd
import matplotlib.pyplot as plt

# ARBOLADO

arbolado = pd.read_csv("/content/drive/MyDrive/Programacion/arbolado-publico-lineal-2017-2018.csv")

#arbolado
#arbolado.head(5)
#arbolado.tail(5)
#arbolado.shap
#arbolado.sample()
#arbolado['nombre_cientifico']
#arbolado['nombre_cientifico'].value_counts()
#arbolado.info()
#arbolado["nro_registro"].count()
#arbolado["nombre_cientifico"].unique()
#arbolado.rename(columns={"long":"logitud"}, inplace=True)
#arbolado.drop(columns="manzana", inplace=True)
#arbolado.columns
# Out:
# <ipython-input-9-2db9f217eb7f>:7: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   arbolado = pd.read_csv("/content/drive/MyDrive/Programacion/arbolado-publico-lineal-2017-2018.csv")
# Index(['long', 'lat', 'nro_registro', 'tipo_activ', 'comuna', 'calle_nombre',
#        'calle_altura', 'calle_chapa', 'direccion_normalizada', 'ubicacion',
#        'nombre_cientifico', 'ancho_acera', 'estado_plantera',
#        'ubicacion_plantera', 'nivel_plantera', 'diametro_altura_pecho',
#        'altura_arbol'],
#       dtype='object')

# %%
# Desafio 
import pandas as pd
import matplotlib.pyplot as plt

mural = pd.read_csv ("/content/drive/MyDrive/Programacion/murales.csv", sep=";")

# 1
# Ultimas tres filas del dataset
#mural.tail(3)

# 2 
# Nombres de las columnas
#mural.columns

# 3
# Que valores toma la columna AUTORES
#mural["AUTORES"].dtypes
#mural.AUTORES.value_counts()

# 4
#mural.F_E.min(skipna=True)

# 5 
#mural.drop(columns='TAMAÑO_TS', inplace=True)
# Out:
# 0      1953.0
# 1      1901.0
# 2      1910.0
# 3      1910.0
# 4      1910.0
#         ...
# 415    1980.0
# 416    1980.0
# 417    1990.0
# 418    1989.0
# 419    1995.0
# Name: F_E, Length: 420, dtype: float64
