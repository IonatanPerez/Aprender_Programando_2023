# %%
# Importamos la libreria
import pandas as pd
murales = pd.read_csv("murales.csv", sep=";")
arbolado = pd.read_csv("arbolado-publico-lineal-2017-2018.csv")



#arbolado.iloc[2,4] # iloc: acceso por número de fila, columna
#arbolado.iloc[1:4, 3] # slice entre fila 1 a 4 (no inclusivo), columa 3
#arbolado.iloc[4, :] # Fila 4 y todas sus columnas  (si no se coloca nada se asume que son todas las columnas)
#arbolado.iloc[:, 2] # Para filtrar toda una columna se debe colocar : en lugar de las filas

#arbolado.loc[1,"nombre_cientifico"] # Fila 1, columa "nombre_cientifico"
arbolado.loc[:, "nombre_cientifico"] # Para ver todos los registros de una columna se debe indicar : en el lugar de las filas
# Out:
# <ipython-input-33-4e6c83cd2cb2>:4: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   arbolado = pd.read_csv("arbolado-publico-lineal-2017-2018.csv")
# 0                   Tipuana tipu
# 1             Peltophorum dubium
# 2         Fraxinus pennsylvanica
# 3         Fraxinus pennsylvanica
# 4          Jacaranda mimosifolia
#                    ...
# 370175            Ceiba speciosa
# 370176           Melia azedarach
# 370177            Ceiba speciosa
# 370178            Ceiba speciosa
# 370179            Ceiba speciosa
# Name: nombre_cientifico, Length: 370180, dtype: object
