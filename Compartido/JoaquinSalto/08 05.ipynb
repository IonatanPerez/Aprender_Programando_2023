# %%
#importamos las librerias que utilizaremos
import pandas as pd
import matplotlib.pyplot as plt   # Solo importamos el módulo pyplot. se podría hacer "from matplotlib import pyplot as plt"
import seaborn as sns

arbolado = pd.read_csv("/content/drive/MyDrive/Programacion/arbolado-publico-lineal-2017-2018.csv")

arbolado["comuna"].value_counts() # Vemos la cantidad de arboles por comuna


### COUNTPLOT ###
# Ahora realizaremos un gráfico de barras que permite visualizar la cantidad de registros por determinada columna.
# En este caso realizaremos un gráfico con la columna "comuna" para contar la cantidad de árboles por comuna (recuerden que cada fila es UN árbol).


#sns.countplot(data=arbolado, x="comuna") # Poniendo eje x, lo que hace es ir de arriba hacia abajo

#sns.countplot(data = arbolado, y="comuna", color="red") # Poniendo el eje y, lo que hace es que va de izq a der


### BARPLOT ###
# Ahora realizaremos un barplot de la librería Seaborn.
# Esto es un gráfico de barras que cruza dos datos, en este caso realizaremos un gráfico similar al anterior pero ahora veremos altura promedio de los arboles por comuna.

#sns.barplot(data= arbolado)



### SCATTERPLOT ###
sns.scatterplot(data=arbolado, x="long", y="lat", color="green")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c56cb0396c74> in <cell line: 6>()
#       4 import seaborn as sns
#       5
# ----> 6 arbolado = pd.read_csv("/content/drive/MyDrive/Programacion/arbolado-publico-lineal-2017-2018.csv")
#       7
#       8 arbolado["comuna"].value_counts() # Vemos la cantidad de arboles por comuna
#
# TypeError: 'str' object is not callable

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#arbolado = pd.read_csv=("/content/drive/MyDrive/Programacion/arbolado-publico-lineal-2017-2018.csv")

arbolado["comuna"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b18b6b350238> in <cell line: 7>()
#       5 #arbolado = pd.read_csv=("/content/drive/MyDrive/Programacion/arbolado-publico-lineal-2017-2018.csv")
#       6
# ----> 7 arbolado["comuna"].value_counts()
#
# TypeError: string indices must be integers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
