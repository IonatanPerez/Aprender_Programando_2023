# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
nombre = input("Ingresa tu nombre: ")
print(f"Hola {nombre}")
# Out:
# Ingresa tu nombre: manu
# Hola manu

# %%
"Hola".upper()
# Out:
# 'HOLA'

# %%
print("¿Te puedo hacer una secuencia de preguntas?")
respuest = input("Responder por si o no: ")
respuesta=respuest.lower()
#poco efecitva la comparacion ya que deja muchas posibildades fuera (sí, Si, si , entre otras )

# Comentario de Ioni: Podes usar .upper() como en el ejemplo de arriba. El tema del acento es mas complicado.


if respuesta == "si":
  print("Pregunta 1")
  print("¿Cuál es el app que más usa?")
  appPrincipal = input("Respuesta: ")
  print("Pregunta 2")
  print("¿Cuál es el trabajo de tus sueños?")
  trabajoSoñado = input("Respuesta: ")
  print("Pregunta 3")
  print("¿A dónde preferirías viajar, al pasado o al futuro?")
  viajeTemporal = input("Respuesta: ")

  print("Gracias por responder las preguntas, ahora puedo formular una breve bio tuya")
  print(f"{nombre} eres una persona que en su celular prefiere usar {appPrincipal} entre las otras decenas de aplicaciones disponibles. Por otra parte, trabajar de/como {trabajoSoñado} sería un sueño en vida para ti. Por último y no menos importante, si existiese la posibilidad de viajar en el tiempo, tu destino sería el {viajeTemporal}.")

else:
  print("Gracias igualmente")
# Out:
# ¿Te puedo hacer una secuencia de preguntas?
# Responder por si o no: NO
# Gracias igualmente

# %% [markdown]
# # Trabajo realizado:
#
# ___
# - __Primer notebook:__
#
# La primer celda de codigo imprime en consola la frase _"Hola mundo"_
# ___
# - __Segunda notebook:__
#
# La segunda celda de codigo pregunta al usuario su nombre y luego lo saluda.
#
# ___
# - __Tercer notrebook:__
#
# El último conjunto de líneas de codigo se encarga de preguntarle al usuario si esta dispuesto a responder una breve encuesta. Si el usuario acepta, se le realizan 3 preguntas, para luego formular una corta biografía sobre el consumidor en base de las preguntas
#
# ___
