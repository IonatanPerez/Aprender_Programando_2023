# %%
print ("Hola mundo")
# Out:
# Hola mundo

# %%
print ("Hola Ionatan")
# Out:
# Hola Ionatan

# %%
print("Hola " + input())
# Out:
# luliiiii
# Hola luliiiii

# %%
" ferritooo "*9
# Out:
# ' ferritooo  ferritooo  ferritooo  ferritooo  ferritooo  ferritooo  ferritooo  ferritooo  ferritooo '

# %%
print ("hOLA"+ input("luliiii"))
# Out:
# luliiiixd
# hOLAxd

# %%
3+7
9+8
# Out:
# 17

# %%
nombre = input("Pone tu nombre: ")
apellido = input("Y tu apellido: ")
print ("Tu nombre completo es: " + nombre + " " + apellido)
# Out:
# Pone tu nombre: luliii
# Y tu apellido: biscayart
# Tu nombre completo es: luliii biscayart
