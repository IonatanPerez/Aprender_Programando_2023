# %%
print ("Hola mundo")
# Out:
# Hola mundo

# %%
nombre = input ("¿Cual es tu nombre?")
print ("Hola:" +" " + nombre)
# Out:
# ¿Cual es tu nombre?Belén
# Hola: Belén

# %%
app = input ("¿Cual es la aplicación que más usas?")
trabajo = input ("¿Que trabajo te gustaría tener?")
viajar = input ("¿Viajarías al pasado o la futuro?")
print = ("Mini BIO" + " " + app + " " + trabajo + " " + viajar)
# Out:
# ¿Cual es la aplicación que más usas?instagram
# ¿Que trabajo te gustaría tener?cirujana
# ¿Viajarías al pasado o la futuro?pasado
