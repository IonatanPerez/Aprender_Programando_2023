# %% [markdown]
# Hacer una linea que imprima "Hola mundo."

# %%
print("hola mundo")

# %% [markdown]
# Hacer una celda que me pregunte el nombre y me salude por mi nombre

# %%
nombre = input("ingrese su nombre ")
print(f"hola {nombre}, te mando saludos!")

# %% [markdown]
# - Hacer una celda que me pregunte:
#   - La app que mas uso
#   - El trabajo que me gustaria tener
#   - Si prefiero viajar al pasado o al futuro
# Y que imprima una breve BIO con esa informacion mia.

# %%
pregunta1 = input("¿Cual es la app que mas usas? ")
pregunta2 = input("¿Cual es el trabajo que te gustaria tener? ")
pregunta3 = input("¿Preferis viajar al pasado o al futuro? ")
print(f"la app que mas uso es {pregunta1} , el trabajo que me gustaria tener es ser {pregunta2} y me gustaria viajar al {pregunta3}. ")
