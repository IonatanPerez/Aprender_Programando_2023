# %%
 print("Hola mundo.")
# Out:
# Hola mundo.

# %%
nombre = input("¿Cual es tu nombre?: ")
print(f"Hola, {nombre}.")
# Out:
# ¿Cual es tu nombre?: Mailen
# Hola, Mailen.

# %%
app = input ( "¿Cual es la app que más usas? ")
trabajo = input ( "¿Que trabajo te gustaria tener? ")
pasado_futuro = input ("¿Preferis viajar al pasado o al futuro? ")
# Out:
# ¿Cual es la app que más usas? Tik Tok
# ¿Que trabajo te gustaria tener? Analista de Datos
# ¿Preferis viajas al pasado o al futuro? Al futuro

# %%
print("BIO:")
print(f"Nombre: {nombre}")
print(f"App más utilizada: {app}")
print(f"Trabajo deseado: {trabajo}")
print(f"Preferencia de viaje en el tiempo: {pasado_futuro}")
# Out:
# BIO:
# Nombre: Mailen
# App más utilizada: Tik Tok
# Trabajo deseado: Analista de Datos
# Preferencia de viaje en el tiempo: Al futuro
