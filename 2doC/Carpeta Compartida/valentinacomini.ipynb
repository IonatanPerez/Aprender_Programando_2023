# %% [markdown]
# **CLASE 1**

# %%
print("Hola mundo.")
# Out:
# Hola mundo.

# %%
nombre = input("Pone tu nombre: ")
apellido = input("Ahora tu apellido: ")
print(f"Hola {nombre} {apellido}")
# Out:
# Pone tu nombre: valu
# Ahora tu apellido: comvaz
# Hola valu comvaz

# %%
nombre = input("Tu nombre es: ")
app = input("La app que más usas: ")
trabajo = input("El trabajo que te gustaría tener: ")
tiempo = input("Preferis viajar al pasado o al futuro: ")
print(f"Breve biografía sobre {nombre}. Utiliza mayormente la aplicación de {app}. Le gustaría tener el trabajo de {trabajo} y preferiría viajar al {tiempo}.")
# Out:
# Tu nombre es: Valu
# La app que más usas: Instagram
# El trabajo que te gustaría tener: Música
# Preferis viajar al pasado o al futuro: Pasado
# Breve biografía sobre Valu. Utiliza mayormente la aplicación de Instagram. Le gustaría tener el trabajo de Música y preferiría viajar al Pasado.

# %%
n1 = int(input("Primer numero: "))
n2 = int(input("Segundo numero: "))
suma = n1 + n2
print(f"El resultado de sumar {n1} mas {n2} es: {suma}")
# Out:
# Primer numero: 23
# Segundo numero: 7
# El resultado de sumar 23 mas 7 es: 30
