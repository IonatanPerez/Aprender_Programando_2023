# %% [markdown]
# -   Hacer una linea que imprima "Hola mundo."
# -   Hacer una celda que me pregunte el nombre y me salude por mi nombre
# -   Preguntar
# -- La app que mas uso
# -- El trabajo que me gustaria tener
# -- Si prefiero viajar al pasado o al futuro Y que imprima una breve BIO con esa informacion mia.

# %%
print("Hello world")
# Out:
# Hello world

# %%
name = input("Ingrese su nombre: "); print(f"Hola {name}")
# Out:
# Ingrese su nombre: A
# Hola A

# %%
usedApp = input("Ingrese la aplicación que más utiliza: "); dreamWk = input("Ingrese su trabajo deseado: "); time = input("¿Dónde viajar?¿pasado o futuro?: ");
# Out:
# Ingrese la aplicación que más utiliza: Instagram
# Ingrese su trabajo deseado: Piloto
# ¿Dónde viajar?¿pasado o futuro?: Futuro

# %%
print(f"#"+name);
print(f'''##Información:
* App más usada: {usedApp}
* Trabajo soñado: {dreamWk}
* En el tiempo, prefiere viajar: {time}''')
# Out:
# #A
# ##Información:
# * App más usada: Instagram
# * Trabajo soñado: Piloto
# * En el tiempo, prefiere viajar: Futuro
