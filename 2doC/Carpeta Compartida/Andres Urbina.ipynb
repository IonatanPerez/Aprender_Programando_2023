# %%
print("HOLA MUNDO")
# Out:
# HOLA MUNDO

# %%
#esta linea no se ejecuta, con numeral

# %%
input("mi nombre es:")
# Out:
# mi nombre es:Andres
# 'Andres'

# %%
print("hola" + input ("pone tu nombre:"))
# Out:
# pone tu nombre:hola
# holahola

# %%
#esta linea no se ejecuta, con numeral
#definimos una variable, por ejemplo la fecha de hoy
fecha_hoy ="18 de Sepitiembre de 2023"
#Usamos esa variabledentro de un print
print (F"hoy es:(fecha_hoy)")
# Out:
# hoy es:(fecha_hoy)

# %%
# QUEREMOS LA FECHA DE mañana
dia= "18"
mes = "Septiembre"
ano = "2023"

# %%
print (f"Mañana es:{int(dia)+1} {mes} de {ano}")
# Out:
# Mañana es:19 Septiembre de 2023

# %%
condicion = False

# %%
type(condicion)
# Out:
# bool

# %%
lista = []
type(lista)
# Out:
# list

# %%
#como ve cuantas cosas tiene una lista?
len(lista)
# Out:
# 0

# %%
lista_super =["Manteca","Arroz"]
# esto tiene dos elementos
print (len(lista_super))
# Out:
# 2

# %%
#manera mala de agregar cosas
lista_super =["Manteca","Arroz","PAN"]
#MANERA BUENA
lista_super.append("pan")
print(lista_super)
# Out:
# ['Manteca', 'Arroz', 'PAN', 'pan']

# %%
lista_super.clear()
# Out:
# <function list.clear()>

# %%
lista_super

# %%
lista_super.appen("Cebolla")

# %%
lista_super +["papa","Manzana"]*3
# Out:
# ['Manteca',
#  'Arroz',
#  'PAN',
#  'pan',
#  'papa',
#  'Manzana',
#  'papa',
#  'Manzana',
#  'papa',
#  'Manzana']

# %%
lista_super.append(3)
# Out:
# ['Manteca', 'Arroz', 'PAN', 'pan']

# %%
lista_super
# Out:
# ['Manteca', 'Arroz', 'PAN', 'pan']

# %%
#otra manera  de acceder al ultimo elemento
lista_super[-1]
# Out:
# 'pan'

# %% [markdown]
# tenemos el siguiente problemas:
# queremos hacer una lista de compra, cada elemento a comprar tiene que ser un item de la lista,pero algunos elementos tengo que comprar mas de uno, ademas a veces(por ejemple en las verduras) hay que indicar la unidad.
# ejemplo:
# quiero comprar:
# -2 Mantecas
# -un kilogramo de papas
# -detergente

# %%
#posible solución
compras=["manteca,manteca"]#esto no funciona si hay cosa que no se miden en objetos
#ha una manera de agrupar informacion de manera conceptual?

# %%
#idea de diccionario

item1= {}
item1["producto"] = "Manteca"
item1["cantidad"] = 2

# %%
item2="Manteca"

# %%
print(item1)
# Out:
# {'nombre_producto': 'Manteca', 'cantidad': 2}

# %%
item1.items()
# Out:
# dict_items([('producto', 'Manteca'), ('cantidad', 2)])

# %%
print (f"Queremos comprar {item1['Cantidad']} unidades de {item1['producto']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-32442b3c7396> in <cell line: 1>()
# ----> 1 print (f"Queremos comprar {item1['Cantidad']} unidades de {item1['producto']}")
#
# KeyError: 'Cantidad'

# %%
# Vamos a armar la lista de supermercado
super = []
item1 = {"Producto" : "Manteca", "Cantidad" : 2}
item2 = {"Producto" : "Papa", "Cantidad": 1, "Unidad": "Kg"}
item3 = {"Producto" : "Huevos", "Cantidad" : 1, "Unidad" : "Docena"}
item4 = {"Producto" : "Detergente"}

super.append(item1)
super.append(item2)
super.append(item3)
super.append(item4)

# %%
print ("Cosas para comprar:")
print (f"{item1['Producto']}")
print (f"{item2['Producto']}")
print (f"{item3['Producto']}")
print (f"{item4['Producto']}")

# %%
print ("Acordate de comprar:")
for pepe in super_vacio:
  print(pepe["Producto"])
print("Chau!")

# %%
super.append({"Producto" : "Alfajor"})
