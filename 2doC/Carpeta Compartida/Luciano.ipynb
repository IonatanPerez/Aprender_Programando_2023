# %%
print("Hola mundo.")
# Out:
# Hola mundo.

# %%
input ()
# Out:
# Luciano
# 'Luciano'

# %%
print ("Hola Ionatan")
# Out:
# Hola Ionatan

# %%
print("hola "+input())
# Out:
# Luciano
# hola Luciano

# %%
nombre = input("Pone tu nombre: ")
apellido = input("Ahora tu apellido: ")
print("tu nombre completo es: "+nombre +" "+apellido)
# Out:
# Pone tu nombre: Luciano
# Ahora tu apellido: Condori
# tu nombre completo es: Luciano Condori

# %%
n1 = input("Primer numero: ")
n2 = input("Segundo numero: ")
suma = n1 + n2
print(f"El resultado de sumar {n1} mas {n2} es: {suma}")
# Out:
# Primer numero: 5
# Segundo numero: 2
# 52
