# %%
print ("Hola mundo.")

# %%
nombre = input("¿Cuál es tu nombre? ")
print("Hola " + nombre + ".")

# %%
print ("Responde a las siguientes preguntas:")
pregunta_1 = input ("1- ¿Cuál es la app que más usas? ")
pregunta_2 = input ("2- Si pudieses tener cualquier trabajo, ¿cuál sería? ")
pregunta_3 = input ("3- ¿Prefieres viajar al pasado o al futuro? ")

# %%
print ("¡Hola! Mi nombre es " + nombre + ".")
print ("Entre las aplicaciones que más uso, sin duda la principal es " + pregunta_1 + ".")
print ("Si tuviese la posibilidad de tener cualquier trabajo del mundo, yo sería... " + pregunta_2 + ".")
print ("Si pudiese viajar al futuro o al pasado, viajaría al " + pregunta_3 + ".")
