# %%
print ("Hola mundo")
# Out:
# Hola mundo

# %%
nombre=input ("Cual es tu nombre?")
print ("Hola,"+nombre)
# Out:
# Cual es tu nombre?male
# Hola,male

# %%
app=input ("Qué app usás más?")
trabajo=input ("Qué trabajo te gudtaría tener?")
respuesta=input ("Viajar al pasado o al futuro")
print ("Tus respuestas:" +" "+app+" "+trabajo+ " "+respuesta)
# Out:
# Qué app usás más?tiktok
# Qué trabajo te gudtaría tener?pastelera
# Viajar al pasado o al futuropasado
# Tus respuestas: tiktok pastelera pasado
