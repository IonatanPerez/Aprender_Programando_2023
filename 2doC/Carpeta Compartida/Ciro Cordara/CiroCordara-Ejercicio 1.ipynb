# %% [markdown]
# # Consigna
#
# - Hacer una linea que imprima "Hola mundo."
# - Hacer una celda que me pregunte el nombre y me salude por mi nombre
# - Hacer una celda que me pregunte:
#   - La app que mas uso
#   - El trabajo que me gustaria tener
#   - Si prefiero viajar al pasado o al futuro
# - Y que imprima una breve BIO con esa informacion mia.
#
# Para quienes ya sepan __programar__, hacer los mismo en una celda markdown con una bio mas completa.

# %% [markdown]
# ***
# - El siguiente programa imprimira Hola Mundo:
# ***

# %%
print("Hola Mundo.")
# Out:
# Hola Mundo.

# %% [markdown]
# ***
# - El siguiente programa nos saludara con nuestro nombre:
# ***

# %%
n=input("Ingrese el nombre: ")
print(f"Hola {n}")
# Out:
# Ingrese el nombre: Ciro
# Hola Ciro

# %% [markdown]
# ***
# - Este programa nos preguntara y guardara informacion nuestra
# ***

# %%
app=input("Ingrese la app que mas usas: ")
trabajo=input("Ingrese el trabajo que nos gustaria tener: ")
pas_fut=input("¿Desea viajar al pasado o al futuro?: ")
# Out:
# Ingrese la app que mas usas: Tik Tok
# Ingrese el trabajo que nos gustaria tener: Arquitecto
# ¿Desea viajar al pasado o al futuro?: Pasado

# %% [markdown]
# #Bibliografia de Ciro

# %% [markdown]
# ---
# ##APP

# %%
print(f"La app que mas usa {n} es {app}.")
# Out:
# La app que mas usa Ciro es Tik Tok.

# %% [markdown]
# >![tiktok-6338430_640.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ##Trabajo

# %%
 print(f"Si tuviese la oportuinidad de elejir libremente su trabajo {n} elijiria ser {trabajo}.")
# Out:
# Si tuviese la oportuinidad de elejir libremente su trabajo Ciro elijiria ser Arquitecto.

# %% [markdown]
# >![arquitectura-1.webp](data:image/webp;base64,...)

# %% [markdown]
# ***
# ##¿Pasado o Futuro?

# %%
 print(f"Si se le presentara la oportunidad de viajar al pasado o al futuro {n} sin dudas elijiria {pas_fut}.")
# Out:
# Si se le presentara la oportunidad de viajar al pasado o al futuro Ciro sin dudas elijiria Pasado.

# %% [markdown]
# > ![pasado3.webp](data:image/webp;base64,...)
