# %%
print("Hola mundo")

# %%
print("Hola",input("Ingrese su nombre: "))

# %%
print("Hola, mi nombre es Zohar, la aplicación que mas utilizo es",input("Ingrese el nombre de la aplicacion que mas utiliza: ")+". El trabajo que más me gustaria tener es",input("Ingrese el trabajo que mas le gustaria tener: ")+". Preferiria viajar al",input("Preferirias viajar al pasado o al futuro: ")+".")
