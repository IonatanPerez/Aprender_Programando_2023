# %%
print ("Hola mundo")
# Out:
# Hola mundo

# %%
nombre = input("¿Cual es tu nombre?")
print ("Hola,"+" "+nombre+". Un placer conocerte. :)")

# %%
aplicacion = input("¿Cual es la aplicacion que usas mas seguido?")
trabajo = input("¿Y que trabajo te gustaria tener si no importara la plata?")
tiempo = input("Si tuvieras que viajar en el tiempo, ¿que eligirias: pasado o futuro?")
print("Tus respuestas fueron: "+aplicacion+", "+trabajo+ " y "+ tiempo+". ")
# Out:
# ¿Cual es la aplicacion que usas mas seguido?Discord o Whatsapp
# ¿Y que trabajo te gustaria tener si no importara la plata?Traductora o algo de informatica
# Si tuvieras que viajar en el tiempo, ¿que eligirias: pasado o futuro?Pasado
# Tus respuestas fueron: Discord o Whatsapp, Traductora o algo de informatica y Pasado.
