# %%
print ("Hola Mundo")

# %%
nombre = input ("¿Cómo te llamás? ")
print ("Hola " + nombre)

# %%
app = input ("¿Cuál es la app que más usás? ")
trabajo = input ("Si pudieras tener cualquier trabajo, ¿cuál sería? ")
viajar = input ("Preferirías viajar al pasado o al futuro? ")

# %%
print ("Hola, me llamo " + nombre + ", la app que más uso es " + app + ", si pudiera tener cualquier trabajo sería " + trabajo + ", y entre el pasado y el futuro, preferiría viajar al " + viajar)
