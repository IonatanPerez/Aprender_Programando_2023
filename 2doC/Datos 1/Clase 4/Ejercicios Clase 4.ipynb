# %% [markdown]
# #### Ejercicios para practicar
#
# Si queres practicar cómo filtrar dataset con la Librería Pandas, animate a hacer estos ejercicios.
#
# Para estos ejercicios vamos a usar el Dataset de Murales del Gobierno de la Ciudad de Buenos Aires extraído de https://data.buenosaires.gob.ar/dataset/murales.
#
# Acordaté cómo subir el Dataset a la Notebook y no te ovides de importar la librería Pandas.
# Por como está armado el archivo es importante que sepas que la separación entre los valores es por punto y coma, para eso vamos a usar el parámetro *sep* del método *read_csv*:
#
# **data=pd.read_csv("Murales.csv", sep=";")**

# %% [markdown]
# 1. Hacé un filtro para ver el Mural más antiguo. Hacer un filtro para ver el Mural más nuevo

# %% [markdown]
# 2. Escribí el código para responder ¿Quién es el AUTOR que más Murales realizó? ¿Cuántos murales realizó? Después hacé un filtro para seleccionar solo los murales de ese Autor

# %% [markdown]
# 3. En base al autor del ejercicio 2, escribí un código para responder ¿Cuál es la técnica que más utilizó? Para eso hacé un DataFrame solo con los Murales de ese autor y luego utilizá *value_counts()* para ver la "TECNICA". Después hacé un filtro del DataFrame de ese AUTOR y la TECNICA que más utilizó

# %% [markdown]
# 4. Hacé un filtro para seleccionar los murales que NO son realizados con la Técnica "MURAL CERAMICO"

# %% [markdown]
# 5. Hacé un filtro de los Murales realizado en el año 1937 y 1938
