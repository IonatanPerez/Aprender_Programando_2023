# %% [markdown]
# ### Desafío 4 - Filtrar un Dataset con la Librería Pandas
#
# Vamos a poner en práctica cómo filtrar un Dataset con lo que que aprendimos de la Librería Pandas.
#
# Para estos ejercicios vamos a usar un dataset extraído de https://data.buenosaires.gob.ar/dataset/murales con la información de los Muralesen la Ciudad de Buenos Aires.
#
# Lo primero que vamos a hacer es subir el Dataset a la Notebook ¿Te acordás cómo se podía hacer?
#
# No te olvides de importar la librería Pandas.
#
# Por como está armado el archivo es importante que sepas que la separación entre los valores es por punto y coma, para eso vamos a usar el parámetro *sep* del método *read_csv*:
#
# **data=pd.read_csv("Murales.csv", sep=";")**

# %% [markdown]
# 1. Hacé un filtro para seleccionar solo los murales realizados en el año 1939

# %% [markdown]
# 2. Hacé un filtro para seleccionar solo los murales que Luis Seoane. ¿Cuántos murales realizó?

# %% [markdown]
# 3. Hacé un filtro para seleccionar los murales que NO son realizados con la Técnica "MURAL CERAMICO"

# %% [markdown]
# 4. Generá un dataset nuevo que solo tenga los Murales realizados con la Técnica "OLEO SOBRE SOPORTE RIGIDO"

# %% [markdown]
# 5. Hacé un filtro seleccionando los Murales realizados por el artista que más Murales realizó. Primero averiguá cuál es artista con *value_counts()* y después hacé el filtro.
