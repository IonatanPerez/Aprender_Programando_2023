# %% [markdown]
# ### Practicá: Limpieza de Datos
#
# Vamos a poner en práctica cómo se hace la limpieza de datos de un Dataset con la librería Pandas.
#
# Para estos ejercicios también vamos a usar el Dataset de Murales del Gobierno de la Ciudad de Buenos Aires extraído de https://data.buenosaires.gob.ar/dataset/murales.
#
# Acordate cómo subir el Dataset a la Notebook y no te ovides de importar la librería Pandas.
# Por como está armado el archivo es importante que sepas que la separación entre los valores es por punto y coma, para eso vamos a usar el parámetro *sep* del método *read_csv*:
#
# **data=pd.read_csv("Murales.csv", sep=";")**

# %% [markdown]
# 1. Escribí un código para responder ¿Qué tipo de dato le asigna a la columna "F_E"? Ahora hacé transformación del tipo de dato para que sea **int**.

# %% [markdown]
# 2. Revisá la cantidad de nulos que hay en el Dataset.

# %% [markdown]
# 3. En la columna "TECNICA" hay varios nulos, eliminá las filas donde hay registros nulos. ¿Qué método tendrías que usar?

# %% [markdown]
# 4. En la columan "AUTORES" hay varios nulos, marcá esos registros reemplazando el nulo por "Anónimo"
