# %% [markdown]
# ### Practicá: Agrupaciones
#
# Vamos a poner en práctica cómo se hacen agrupaciones de los Datos con la librería Pandas.
#
# Para estos ejercicios también vamos a usar el Dataset de Murales del Gobierno de la Ciudad de Buenos Aires extraído de https://data.buenosaires.gob.ar/dataset/murales.
#
# Acordate cómo subir el Dataset a la Notebook y no te ovides de importar la librería Pandas.
# Por como está armado el archivo es importante que sepas que la separación entre los valores es por punto y coma, para eso vamos a usar el parámetro *sep* del método *read_csv*:
#
# **data=pd.read_csv("Murales.csv", sep=";")**

# %% [markdown]
# 1. Hacé un agrupamiento con la columna "TECNICA" y utilizá el método *size()* para ver la cantidad qué hay de cada uno

# %% [markdown]
# 2. Hacé un agrupamiento con las columnas "AUTORES" y "TECNICA" y utilizá el método *count()* sobre la columna "NOMBRE_OBRA" para ver las cantidades de cada combinación

# %% [markdown]
# 3. Sobre el agrupamiento que hiciste, tratá de ordenar la agrupación devuelta usando el método *sort_values()*, ordenalos de mayor a menor utilizando el parámetro *ascending=False*
#
#   ¿Cuántos Murales con la Técnica Oleo S/Tela pintó Benito Quinquela Martin?
