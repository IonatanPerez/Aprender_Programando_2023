# %% [markdown]
# ### Desafio 5: Visualizaciones
#
# Vamos a poner en práctica cómo hacer gráficos con las Librerías Matplotlib y Seaborn.
#
# Para estos ejercicios vamos a usar el dataset del Arbolado de la Ciudad de Buenos Aires extraído de
# https://data.buenosaires.gob.ar/dataset/arbolado-publico-lineal.
#
# Lo primero que vamos a hacer es subir el Dataset a la Notebook ¿Te acordás cómo se podía hacer? Y después vamos a empezar a hacer gráficos.
#
# No te olvides de importar las librerías Pandas, Matplotlib y Seaborn .

# %% [markdown]
# 1. Hacé un gráfico que muestre cuántos arboles de *Tipuana tipu*hay en cada comuna. Primero hacé un DataFrame filtrando por *nombre_científico* y después hacé el gráfico.

# %% [markdown]
# 2. Hacé un gráfico que muestre el ancho de los árboles por comuna ¿Qué comunas tienen arboles más anchos?

# %% [markdown]
# 3. Hacé un gráfico que muestre la distribución del ancho de los árboles, ¿Qué ancho tienen la mayoría de los arboles?

# %% [markdown]
# 4. Escribí un código que permita responder a la pregunta ¿Cuál es la calle con más arboles? Primeró hacé un *value_counts()* para saber cuál es la calle con más árboles y después hace un DataFrame filtrando solamente los árboles de esta calle.
#
#   Hacé un gráfico *displot* con la *altura_arbol* y el *diametro_altura_pecha* de los arboles de esa calle (del DataFrame filtrado)
