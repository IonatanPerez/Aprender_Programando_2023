# %% [markdown]
# #### Ejercicios  para practicar
#
# Para practicar cómo hacer gráficos dataset con las Librerías Matplotlib y Seaborn, animate a hacer estos ejercicios extra optativos.
#
# Para estos ejercicios vamos a usar el dataset del Arbolado de la Ciudad de Buenos Aires extraído de
# https://data.buenosaires.gob.ar/dataset/arbolado-publico-lineal.
#
# Acordate cómo subir el Dataset a la Notebook y no te ovides de importar la librería Pandas, Matplotlib y Seaborn.

# %% [markdown]
# 1. Hacé un gráfico que muestre cuántos arboles de *Jacaranda mimosifolia* hay en cada comuna. Primero vas a tener que hacer un filtro por *nombre_científico* y después con el DataFrame filtrado realizá el gráfico.

# %% [markdown]
# 2. Hacé un DataFrame que solamente tenga los árboles *Tipuana tipu*, *Jacaranda mimosifolia* y *Fraxinus americana* (filtrando). Después hacé un gráfico de ese DataFrame que muestre la cantidad de arboles de cada tipo.

# %% [markdown]
# 3. Hacé un gráfico para ver la distribución de la altura de los árboles del DataFrame filtrado del ejercicio anterior

# %% [markdown]
# 4. Hacé un gráfico que muestre la relación entre la altura y el ancho de los árboles del DataFrame del ejercicio 2
