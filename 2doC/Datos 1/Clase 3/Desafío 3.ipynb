# %% [markdown]
# ### Clase 3: Introducción a Pandas
#
# Vamos a poner en práctica algunos métodos que aprendimos de la Librería Pandas.
#
# Para estos ejercicios vamos a usar un dataset extraído de https://data.buenosaires.gob.ar/dataset/murales con la información de los Muralesen la Ciudad de Buenos Aires.
#
# Lo primero que vamos a hacer es subir el Dataset a la Notebook ¿Te acordás cómo se podía hacer?
#
# No te olvides de importar la librería Pandas:

# %% [markdown]
# Por como está armado el archivo es importante que sepas que la separación entre los valores es por punto y coma, para eso vamos a usar el parámetro *sep* del método *read_csv*:
#
# **data=pd.read_csv("Murales.csv", sep=";")**

# %% [markdown]
# 1. Escribí un código para ver los primeros 5 registros del dataset.

# %% [markdown]
# 2. Escribí un código para ver los nombres de las columnas

# %% [markdown]
# 3. Seleccioná la columna "AUTORES". Escribí un código para ver qué valores toma y otra línea para ver cuántos registros hay de cada uno.

# %% [markdown]
# 3. Escribí un cóidigo que responda ¿Cuál es el mural más antigûo? ¿En qué año se hizo?

# %% [markdown]
# 4. Eliminá la columna "TAAÑO_TS

# %% [markdown]
# 5. Cambiá los nombres de todas las columnas a minuscula
