# %% [markdown]
# #### Ejercicios para practicar
#
# Si queres seguir practicando la exploración de datos con la Librería Pandas, animate a hacer estos ejercicios.
#
# Para estos ejercicios vamos a usar el Dataset de Murales del Gobierno de la Ciudad de Buenos Aires extraído de https://data.buenosaires.gob.ar/dataset/murales.
#
# Acordaté cómo subir el Dataset a la Notebook y no te ovides de importar la librería Pandas.
# Por como está armado el archivo es importante que sepas que la separación entre los valores es por punto y coma, para eso vamos a usar el parámetro *sep* del método *read_csv*:
#
# **data=pd.read_csv("Murales.csv", sep=";")**

# %% [markdown]
# 1. Escribí un código para ver los últimos 5 registros del dataset

# %% [markdown]
# 2. Escribí un código que devuelva una muestra aleatoria de 6 murales

# %% [markdown]
# 3. Escribí un código que devuelva cuáles son las posibles "TECNICAS y otro para ver cuántos registros hay de cada una

# %% [markdown]
# 4. Escribí un código que responda ¿Hay más de un mural con el mismo nombre?

# %% [markdown]
# 5. Modificá el nombre de la columna "F_E"

# %% [markdown]
# 6. Eliminá la columna "UBICACION". ¿Cuál es el código para eliminar dos columnas a la vez?
