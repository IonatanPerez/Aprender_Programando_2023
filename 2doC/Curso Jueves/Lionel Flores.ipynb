# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
print(print)
# Out:
# <built-in function print>

# %%
print("print")
# Out:
# print

# %%
print("Hola Ionatan")
# Out:
# Hola Ionatan

# %%
print("Hola")

# %%
nombre_persona = input()
# Out:
# Ionatan

# %%
print("Hola " + nombre_persona)
# Out:
# Hola Ionatan

# %%
nombre_persona
# Out:
# 'Ionatan'
