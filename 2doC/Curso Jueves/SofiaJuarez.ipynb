# %%
print("Hola mundo.")
# Out:
# Hola mundo.

# %%
print(print)
# Out:
# <built-in function print>

# %%
print("print")
# Out:
# print

# %%
input()
# Out:
# Sofia
# 'Sofia'

# %%
nombre_persona = input()
# Out:
# Sofia

# %%
nombre_persona
# Out:
# 'Sofia'

# %%
print("Hola " + nombre_persona)
# Out:
# Hola Sofia

# %%
apellido_persona = input()
# Out:
# Juarez

# %%
print("Hola " + nombre_persona, apellido_persona)
# Out:
# Hola Sofia Juarez

# %%
nombre_persona = input("Por favor, ingrese su nombre:")
apellido_persona = input("Por favor, ingrese su apellido:")
print(f"Hola {nombre_persona} {apellido_persona}, Muchas gracias por darnos sus datos.")
# Out:
# Por favor, ingrese su nombre:Sofia
# Por favor, ingrese su apellido:Juarez
# Hola Sofia Juarez, Muchas gracias por darnos sus datos.

# %%
Primer_sumando = input("Ingrese el primer número a sumar: ")
Primer_sumando = int(Primer_sumando)
Segundo_sumando = input("Ingrese el segundo número a sumar: ")
Segundo_sumando = int(Segundo_sumando)
Suma = Primer_sumando + Segundo_sumando
print(f"El resultado de sumar {Primer_sumando} más {Segundo_sumando} es: {suma}")
# Out:
# Ingrese el primer número a sumar: 7
# Ingrese el segundo número a sumar: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e152e84d8095> in <cell line: 6>()
#       4 Segundo_sumando = int(Segundo_sumando)
#       5 Suma = Primer_sumando + Segundo_sumando
# ----> 6 print(f"El resultado de sumar {Primer_sumando} más {Segundo_sumando} es: {suma}")
#
# NameError: name 'suma' is not defined
