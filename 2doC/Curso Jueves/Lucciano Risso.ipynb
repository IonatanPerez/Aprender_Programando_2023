# %% [markdown]
# Clase 1

# %%
print ("hola mundo. ")
# Out:
# hola mundo.

# %%
input()
# Out:
# hola
# 'hola'

# %%
nombre = input("ingrese su nombre ")
print("hola " + nombre)
# Out:
# ingrese su nombre lucciano
# hola lucciano

# %%
N1 = input()
N1 = float
N2 = input()
# Out:
# 1
# 2

# %% [markdown]
# clase 2

# %%
l = ["nombre1","nombre 2","nombre3"]

# %%
l[0]
# Out:
# 'nombre1'

# %%
l[-1]
# Out:
# 'nombre3'
