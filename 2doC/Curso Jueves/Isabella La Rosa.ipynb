# %%
print ("hola mundo")
# Out:
# hola mundo

# %%
a = 4+5
print(a)
# Out:
# 9

# %% [markdown]
# sirve para suma resta o multiplicación, no hace falta declarar la variable

# %%
nombre = "Alicia"
edad = 35
print("Me llamo", nombre, "y tengo", edad, "años.")
# Out:
# Me llamo Alicia y tengo 35 años.

# %% [markdown]
# juntamos un string con un int y lo colocamos en un print. Todo junto, separado por "" y comas

# %%
a= 6
b= 5
print("la multiplicación entre", a, "y", b, "es:", a*b)
# Out:
# la multiplicación entre 6 y 5 es: 30

# %% [markdown]
# no hace falta poner espacios entre las variables en el print, ya vienen incluidas

# %%
nombre_persona = input("ingrese su nombre: ")
apellido_persona = input("ahora ingrese su apellido: ")
# Out:
# ingrese su nombre: isabella
# ahora ingrese su apellido: la rosa

# %%
print("hola " + nombre_persona, apellido_persona)
# Out:
# hola isabella la rosa

# %%
print(f"Hola {nombre_persona} {apellido_persona}")
# Out:
# Hola isabella la rosa

# %% [markdown]
# ejemplo profe con el +.
# dentro de los () de los prints se puede colocar el texto previo para ingresar

# %%
num1 = int(input("ingrese un numero: "))
num2 = int(input("ingrese otro numero: "))
suma = num1 + num2
print ("la suma de los dos numero es:", suma)
# Out:
# ingrese un numero: 7
# ingrese otro numero: 3
# la suma de los dos numero es: 10

# %% [markdown]
# con la funcion int, transformamos un str a un int como tal. podemos almacenarlo en alguna variable y de ahi hacer lo que queramos
