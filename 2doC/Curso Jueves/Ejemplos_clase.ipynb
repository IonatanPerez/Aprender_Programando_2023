# %%
print("Hola mundo.")
# Out:
# Hola mundo.

# %%
resultado = 42
print(f"El resultado de sumar 2 + 3 es: {resultado}")
# Out:
# El resultado de sumar 2 + 3 es: 42

# %%
frase = "Hola como andas? Esto es un ejemplo"

# %%
def suma(numero1, numero2):
  display(numero1 + numero2)

# %%
suma(2,"3")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-7d53d2382e16> in <cell line: 1>()
# ----> 1 suma(2,"3")
#
# <ipython-input-71-4643a90fdbf7> in suma(numero1, numero2)
#       1 def suma(numero1, numero2):
# ----> 2   display(numero1 + numero2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print("Hola Ionatan!")
# Out:
# Hola Ionatan!

# %%
print("Hola")

# %%
nombre_persona = input("Por favor, ingrese su nombre: ")
apellido_persona = input("Por favor, ingrese su apellido: ")
print(f"Hola {nombre_persona} {apellido_persona}, muchas gracias por darnos sus datos.")
# Out:
# Por favor, ingrese su nombre: Ionatan
# Por favor, ingrese su apellido: Perez
# Hola Ionatan Perez, muchas gracias por darnos sus datos.

# %%
print("Hola " + nombre_persona + " " + apellido_persona)
# Out:
# Hola Ionatan Perez

# %%
print(f"Hola {nombre_persona} {apellido_persona}")

# %%
nombre_persona
# Out:
# 'Ionatan'

# %%
primer_sumando = input("Ingrese el primer numero a sumar ")
primer_sumando = int(primer_sumando)
segundo_sumando = int(input("Ingrese el segundo numero a sumar "))

suma = primer_sumando + segundo_sumando
print(f"El resultado de sumar {primer_sumando} mas {segundo_sumando} es: {suma}")
# Out:
# Ingrese el primer numero a sumar tres
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-fdf2de0b1f59> in <cell line: 2>()
#       1 primer_sumando = input("Ingrese el primer numero a sumar ")
# ----> 2 primer_sumando = int(primer_sumando)
#       3 segundo_sumando = int(input("Ingrese el segundo numero a sumar "))
#       4
#       5 suma = primer_sumando + segundo_sumando
#
# ValueError: invalid literal for int() with base 10: 'tres'

# %%
type(nombre_persona)
# Out:
# str

# %% [markdown]
# Existen los datos tipo flotante

# %%
def sumar_numero():
  print("Ingrese el primer numero")
  numero1 = float(input())
  print("Ingrese el segundo numero")
  numero2 = float(input())
  print(f"El resultado es: {numero1 + numero2}")

# %%
saludar_persona()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-724b5c349f7f> in <cell line: 1>()
# ----> 1 saludar_persona()
#
# <ipython-input-44-e8fb7ab6fa83> in saludar_persona()
#       1 def saludar_persona():
# ----> 2   nombre_persona = input("Por favor, ingrese su nombre: ")
#       3   apellido_persona = input("Por favor, ingrese su apellido: ")
#       4   print(f"Hola {nombre_persona} {apellido_persona}, muchas gracias por darnos sus datos.")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
