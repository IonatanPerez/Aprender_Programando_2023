# %%
    nombre_persona = input("Por favor, ingrese su nombre: ")
apellido_persona = input("Por favor, ingrese su apellido: ")
print(f"Hola {nombre_persona} {apellido_persona}, muchas gracias por darnos sus datos.")
# Out:
# Por favor, ingrese su nombre: mariana
# Por favor, ingrese su apellido: facundo0
# Hola mariana facundo0, muchas gracias por darnos sus datos.

# %%
pedidos_Ariel = input("por favor,ingrese productos: ")
nombre_cliente = input("por favor, ingrese su nombre: ")
print(f"Hola {nombre_cliente} {pedidos_ariel}, muchas gracias por darnos sus datos." )print(f"Hola {nombre_persona} {apellido_persona}, muchas gracias por darnos sus datos."

# %%
nombre_persona = input("por favor, ingrese su nombre: ")
apellido_persona= input("por favor, ingrse su apellido ")
print(f"Hola {nombre_persona} {apellido_persona}, muchas gracias por darnos sus datos.")
# Out:
# por favor, ingrese su nombre: Ariel
# por favor, ingrse su apellido intraub
# Hola Ariel intraub, muchas gracias por darnos sus datos.

# %%
speed_bebida = input("por favor, digame a quien le gusta esta bebida: ")
# Out:
# por favor, digame a quien le gusta esta bebida: agustina

# %%
num1=int(5);
num2=int(9);

suma=num1+num2;

print(suma)
# Out:
# 14

# %%
print("hola mundo. ")
# Out:
# hola mundo.
