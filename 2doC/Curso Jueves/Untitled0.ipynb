# %%
print("Hola mundo.")
# Out:
# Hola mundo.

# %%
nombre_persona = input("Porfavor ingrese su nombre:")
apellido_persona = input("Porfavor ingrese su apellido:")
print("Hola" , nombre_persona , apellido_persona ,  "Muchas gracias por ingresar sus datos" )
# Out:
# Porfavor ingrese su nombre:Moro
# Porfavor ingrese su apellido:Ferrer
# Hola Moro Ferrer Muchas gracias por ingresar sus datos
