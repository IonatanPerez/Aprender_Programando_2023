# %%
print ("Hola Mundo!")
# Out:
# Hola Mundo!

# %% [markdown]
# Clase 1

# %%
print("print")
# Out:
# print

# %%
nombre_persona = input("Ingrese su nombre ")
# Out:
# Ingresar nombre Tiziana

# %%
apellido_persona = input("Ingrese su apellido ")
# Out:
# Ingrese su apellido Guala

# %%
print("Hola "+nombre_persona +" " +apellido_persona)
# Out:
# Hola Tiziana Guala

# %%
n1 = int(input("Ingrese el número a sumar "))
# Out:
# Ingrese el número a sumar 3

# %%
n1 = int(n1)

# %%
n2 = input ("Ingrese el segundo número")
# Out:
# Ingrese el segundo número4

# %%
n1 = 3

# %%
n2 = 4

# %%
n2 = int(n2)

# %%
suma = n1 +n2

# %%
print("El resultado de sumar" +n1 + "más" +n2 +"es:" +suma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c3e0e7ba14ab> in <cell line: 1>()
# ----> 1 print("El resultado de sumar" +n1 + "más" +n2 +"es:" +suma)
#
# NameError: name 'n1' is not defined

# %%
type(nombre_persona)

# %% [markdown]
# Desafío 1

# %%
materias = ["Matemática","Física","Química"]

# %%
materias.remove("Matemática")
print(materias)
# Out:
# ['Física', 'Química']

# %%
materias = ["Matemática","Física","Química"]
materias.append("Lengua")
print(materias)
# Out:
# ['Matemática', 'Física', 'Química', 'Lengua']

# %%
materias = ["Matemática","Física","Química"]
materias[1]
# Out:
# 'Física'
