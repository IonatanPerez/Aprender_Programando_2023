# %%
print("hola mundo")
# Out:
# hola mundo

# %%
name = input()  print("Ingrese su nombre")
apellido = input()  print("ingrese su apellido :")
print (f'' + name , + apellido)
# Out:
#   File "<ipython-input-6-fac4ce73cd94>", line 1
#     name = input()  print("Ingrese su nombre")
#                     ^
# SyntaxError: invalid syntax
