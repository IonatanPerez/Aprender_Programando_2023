# %%
print("Hola mundo.")
# Out:
# Hola mundo.

# %% [markdown]
# Hola

# %%
primer_sumando = input("Ingresar primer sumando: ")
primer_sumando = int
segundo_sumando = input ("Ingresar segundo sumando: ")
segundo_sumando = int
suma = input(primer_sumando segundo_sumando)
suma = int
# Out:
# Ingresar primer sumando: 1
# Ingresar segundo sumando: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-41321c17f297> in <cell line: 5>()
#       3 segundo_sumando = input ("Ingresar segundo sumando: ")
#       4 segundo_sumando = int
# ----> 5 suma = input(primer_sumando + segundo_sumando)
#       6 suma = int
#
# TypeError: unsupported operand type(s) for +: 'type' and 'type'
