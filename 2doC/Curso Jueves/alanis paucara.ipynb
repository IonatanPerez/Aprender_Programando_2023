# %%
print("hola mundo.")
# Out:
# hola mundo.

# %%
print(print)
# Out:
# <built-in function print>

# %%
print("print")
# Out:
# print

# %%
input()
# Out:
# alanis
# 'alanis'

# %%
nombre_persona = input()
# Out:
# alanis

# %%
nombre_persona = input("por favor, ingrese su nombre: ")
apellido_persona = input("por favor, ingrese su apellido: ")
# Out:
# por favor, ingrese su nombre: alanis
# por favor, ingrese su apellido: paucara

# %%
nombre_persona = input("por favor ingrese su nombre: ")
apellido_persona = input("por favor, ingrese su apellido: ")
print(f"hola {nombre_persona} {apellido_persona}, muchas gracias por darnos sus datos.")
# Out:
# por favor ingrese su nombre: alanis
# por favor, ingrese su apellido: paucara
# hola alanis paucara, muchas gracias por darnos sus datos.

# %%
primer_sumando = input("ingrese el primer numero a sumar:")
primer_sumando = int("primer sumando")
segundo_sumando = int(input("ingrese el segundo numero a sumar:"))
# Out:
# ingrese el primer numero a sumar:7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-32d0f7b4be5d> in <cell line: 2>()
#       1 primer_sumando = input("ingrese el primer numero a sumar:")
# ----> 2 primer_sumando = int("primer sumando")
#       3 segundo_sumando = int(input("ingrese el segundo numero a sumar:"))
#
# ValueError: invalid literal for int() with base 10: 'primer sumando'
