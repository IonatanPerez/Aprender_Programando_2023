# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
nombre_persona = input("Por favor ingrese su nombre: ")
apellido_persona = input("Por favor ingrese su apellido: ")
print(f"Hola {nombre_persona} {apellido_persona},gracias por darnos sus datos")
# Out:
# Por favor ingrese su nombre: facu
# Por favor ingrese su apellido: cass
# Hola facu cass,gracias por darnos sus datos

# %%
n1= "Facundo"
n2= "Juan"
n3= "Maxi"

# %%
l = ["Facundo", "Juan", "Maxi"]

# %%
l[1]
# Out:
# 'Juan'

# %%
len(l)
# Out:
# 3

# %%
l.append?
