# %%
nombre_persona = input ("inserte su nombre: ")
apellido_persona = input ("inserte su apellido: ")

print("Hola " + nombre_persona + " " + apellido_persona)
# Out:
# inserte su nombre: Agustin
# inserte su apellido: Sanchez
# Hola Agustin Sanchez

# %%
from IPython.utils.text import string
primer_sumando = input("ingrese el primer numero a sumar: ")
int (primer_sumando)
segundo_sumando = input ("ingrese el segundo numero a sumar: ")
int (segundo_sumando)
suma = primer_sumando + segundo_sumando
print("Resultado: " + suma)
# Out:
# ingrese el primer numero a sumar: 6
# ingrese el segundo numero a sumar: 7
# Resultado: 67
