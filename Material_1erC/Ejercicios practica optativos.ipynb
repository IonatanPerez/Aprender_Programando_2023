# %% [markdown]
# ## Ejercitación de práctica optativos

# %% [markdown]
# #### Tipos de datos
#
# 1. Armar una lista con 6 ciudades
#
# 2. Seleccionar la segunda ciudad
#
# 3. Eliminar la última ciudad
#
# 4. Reemplazar la primer ciudad con otra
#
# 5. Agregar una ciudad al final
#
# 6. Armar un diccionario que tenga 3 duplas de Provincia y Capital (ej: "Provincia de Buenos Aires: La Plata")
#
# 7. Eliminar el último registro (dupla Capital-Provincia)
#
# 8. Ver todas las claves (*keys*)

# %% [markdown]
# #### Estructuras de Control
#
# 1. Como en una playa, crear una estructura condicional donde si la bandera es igual a "roja", imprima "prohibición de baño", si es "roja con negro", imprima "mar peligroso"; si es "amarilla con negro", imprima "mar dudoso" y si es "celeste" imprima "mar calmo"
#
# 2. Crear una estructura condicional que indique que si la bandera es "roja" **o** "llueve", imprima "no puedo entrar al mar"
#
# 3. Crear una estructura condicional que indique que si "no llueve" **y** la bandera es "celeste" imprima "puedo entrar al mar"
#
# 4. Crear una lista de ciudades (puede ser la del ejercicio anterior). Crear una estructura de iteración donde cuente la cantidad de ciudades en la lista
#
# 5. Crear una lista de números y crear una estructura de iteración donde se vayan multiplicando e imprima el resultado final
#
# 6. Crear una función que reciba como argumento 2 números y los multiplique
#
# 7. Crear una función que reciba el color de una bandera e imprima el significado (combinar función con estructura condicional)

# %% [markdown]
# #### Exploración de dataset
#
# Para esta ejercitación utilizaremos un dataset extraído de https://data.buenosaires.gob.ar/dataset/murales
#
# Registro de murales relevados por la Comisión para la Preservación del Patrimonio Histórico Cultural de la Ciudad de Buenos Aires con la ubicación, artista, tamaño y nombre de la obra.

# %%
#Importamos la librería que utilizaremos

import pandas as pd

# %%
# Archivo desde Drive

from google.colab import drive
drive.mount('/content/drive')

# %%
# Archivo desde computadora

from google.colab import files
import io

filesUploaded = files.upload()

# %% [markdown]
# ### Ejercicios pandas 1: exploración
#
# 1. Ver los últimos 5 registros del dataset
#
# 2. Ver una muestra aleatoria de 6 murales
#
# 3. Ver las "TECNICAS" posibles. Ver cuántos registros hay de cada una
#
# 4. ¿Hay más de un mural con el mismo nombre?
#
# 5. Modificar el nombre de la columna "F_E"
#
# 6. Eliminar la columna "UBICACION". ¿Cuál es el código para eliminar dos columnas a la vez?

# %% [markdown]
# #### Ejericios pandas 2: filtrar
#
# 1. Hacer un filtro para ver el Mural más antiguo. Hacer un filtro para ver el Mural más nuevo
#
# 2. ¿Quién es el AUTOR que más Murales realizó? ¿Cuántos murales realizó? Hacer un filtro para seleccionar solo los murales de ese Autor
#
# 3. De los Murales de ese AUTOR ¿Cuál es la técnica que más utilizó? Hacer un filtro solamente con el AUTOR que más Murales realizó y la Técnica que más utilizó
#
# 4. Hacer un filtro para seleccionar los murales que NO son realizados con la Técnica "MURAL CERAMICO"
#
# 5. Hacer un filtro de los Murales realizado en el año 1937 y 1938

# %% [markdown]
# #### Visualizaciones

# %% [markdown]
# Para estos ejercicios vamos a usar el dataset del Arbolado Pùblico de la Ciudad que hemos utilizado en las clases

# %%
data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")

# %% [markdown]
# 1. Hacer un gráfico que muestre cuántos arboles de *Jacaranda mimosifolia* hay en cada comuna. Primero realizar un filtro por nombre_científico y luego realizar el gráfico.
#
# 2. Hacer un DataFrame con los arboles *Tipuana tipu*, *Jacaranda mimosifolia* y *Fraxinus americana*. Hacer un gráfico que muestre la cantidad de arboles de cada tipo.
#
# 3. Hacer un gráfico para ver la distribución de la altura de los árboles del DataFrame del ejercicio anterior
#
# 4. Hacer un gráfico que muestre la relación entre la altura y el ancho de los árboles del DataFrame del ejercicio 2
