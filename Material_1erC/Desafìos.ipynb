# %% [markdown]
# ## Desafíos

# %% [markdown]
# ### Desafío 1 - Listas
#
# 1. Hacer una lista que contenga 3 materias de la escuela
#
# 2. Eliminar el primer registro de la lista
#
# 3. Agregar una materia más al final
#
# 4. Seleccionar el segundo elemento de la lista

# %% [markdown]
# ### Desafío 2 - Estructuras de Control
#
# 1. Definir 2 variables con números (num1 y num2). Crear una estructura condicional donde si los dos números son iguales se imprima "los dos números son iguales" (*if... else...*)
#
# 2. Crear una estructura condicional donde si "no llueve", "podemos ir a la plaza" y sino "debemos quedarnos en casa" (*if... else...*)
#
# 3. Definir una lista con 3 números. Crear una estructura iterativa donde se imprima cada número +2 (*for... in...*)
#
# 4. Crear una función que dado 2 números (parámetros), imprima el resultado de dividir el primer nùmero por el segundo (*def*)
#
# 5. Crea una función que reciba 2 números e incluya un condicional donde si el segundo número es 0 imprima "no se puede realizar esta operación" y sino realice una división entre el primer y el segundo número.

# %% [markdown]
# ### Ejercicios Dataset pandas
#
# Para estos ejercicios utilizaremos un dataset extraído de https://data.buenosaires.gob.ar/dataset/murales con la información de los Muralesen la Ciudad de Buenos Aires.
#
# Dado como está armado el archivo es importante aclarar que la separación de valores es por punto y coma a través del parámetro sep:
#
# *data=pd.read_csv("Murales.csv", sep=";")*

# %%
import pandas as pd

# %%
# Archivo desde Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Archivo desde computadora

from google.colab import files
import io

filesUploaded = files.upload()

# %%
data = pd.read_csv("Murales.csv", sep=";")

# %% [markdown]
# ### Desafío 3: Pandas

# %% [markdown]
# 1. Ver los primeros 5 registros del dataset.
#
# 2. Ver los nombres de las columnas
#
# 3. Seleccionar la columna "AUTORES". Ver que valores toma esa columna y cuántos registros hay de cada uno.
#
# 3. ¿Cuál es el mural más antigûo? ¿En qué año se hizo? ¿Quién es el autor?
#
# 4. Eliminar la columna "TAAÑO_TS
#
# 5. Cambiar los nombres de todas las columnas a minuscula

# %% [markdown]
# ### Desafio 4: Pandas filtros
#
# 1. Hacer un filtro para seleccionar solo los murales realizados en el año 1939
#
# 2. Hacer un filtro para seleccionar solo los murales que Luis Seoane. ¿Cuántos murales realizó? ¿Cuál fue el primero?¿Y el úlitmo?
#
# 3. Hacer un filtro para seleccionar los murales que NO son realizados con la Técnica "MURAL CERAMICO"
#
# 4. Generar un dataset filtrando los Murales realizados con la Técnica "OLEO SOBRE SOPORTE RIGIDO"
#
# 5. Filtrar el DataFrame seleccionando los Murales realizados por el artista que más Murales realizó

# %% [markdown]
# ### Desafio 5: Visualizaciones
#
# Para este Desafío vamos a utilizar el Dataset del Arbolado que venimos utilizando

# %%
data = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")

# %% [markdown]
# 1. Hacer un gráfico que muestre cuántos arboles de *Tipuana tipu*hay en cada comuna. Primero realizar un filtro por *nombre_científico* y luego realizar el gráfico.
#
# 2. Hacer un gráfico que muestre el ancho de los árboles por comuna ¿Qué comunas tienen arboles más anchos?
#
# 3. Realizar un gráfico que muestre la distribución del ancho de los árboles, ¿Qué ancho tienen la mayoría de los arboles?
#
# 4. ¿Cuál es la calle con más arboles? Realizar un *value_counts()*. Realizar un gráfico *displot* con la *altura_arbol* y el *diametro_altura_pecho* de los arboles de esa calle (para eso se debe filtrar el dataset)

# %% [markdown]
# ### Desafío 6: Buscar Datasets
#
# El objetivo es ponerse en grupos y buscar dataset que sean de su interés para poder realizar un análisis. Puede ser de cualquier tema que les interese que puedan contar con Datos. Les dejamos un Documento de Google con sitios donde pueden buscar datasets, es un Documento colaborativo entre todas las comisiones de Datos asì que pueden agregar: [Dataset](https://docs.google.com/document/d/1EnimkrV_a9cu-ZrrcydZnigquQeGSpUsnqu0BA3fUFE/edit?usp=sharing!)

# %% [markdown]
# ## Proyecto Final
#
# El Proyecto final se realizará en grupos y la propuesta es realizar un Proyecto de Análsis de Datos utilizando Python.
#
# * Definición del problema
# * Búsqueda de datos
# * Análisis exploratorio
# * Limpieza
# * Visualizaciones
# * Presentación de resultados.
